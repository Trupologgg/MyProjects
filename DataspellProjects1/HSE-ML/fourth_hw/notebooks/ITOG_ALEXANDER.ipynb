# %% [markdown]
# # HSE 2021: Mathematical Methods for Data Analysis
#
# ## Homework 4
#
# **Warning 1**: You have 2 weeks for this assignemnt.  **it is better to start early (!)**
#
# **Warning 2**: it is critical to describe and explain what you are doing and why, use markdown cells
#
#
# ### Contents
#
# #### Decision Trees - 7 points
# * [Task 1](#task1) (0.5 points)
# * [Task 2](#task2) (0.5 points)
# * [Task 3](#task3) (2 points)
# * [Task 4](#task4) (0.5 points)
# * [Task 5](#task5) (0.5 points)
# * [Task 6](#task6) (2 points)
# * [Task 7](#task7) (0.5 points)
# * [Task 8](#task8) (0.5 points)
#
# #### Ensembles - 3 points
# * [Task 1](#task2_1) (1 point)
# * [Task 2](#task2_2) (0.7 points)
# * [Task 3](#task2_3) (0.5 points)
# * [Task 4](#task2_4) (0.7 points)
# * [Task 5](#task2_5) (0.1 points)

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

plt.rcParams['figure.figsize'] = (11, 5)
# %matplotlib inline

# %% [markdown]
# # Part 1. Decision Tree Regressor

# %% [markdown]
# In this task you will be implementing decision tree for the regression by hand.

# %% [markdown]
# ### Task 1 <a id="task1"></a> (0.5 points)
#
# Here you should implement the function `H()` which calculates impurity criterion. We will be training regression tree, and will take mean absolute deviation as impurity criterion.
#
# * You cannot use loops
# * If `y` is empty, the function should return 0

# %%
def H(y):
    # if len(y) == 0:
    #     return 0
    # return float(pd.DataFrame(y).var(ddof=0))   #Too long idk
    if len(y) == 0:
        return 0
    else:
        return np.var(y)

# %%
# Test the function
assert np.allclose(H(np.array([4, 2, 2, 2])), 0.75)
assert np.allclose(H(np.array([])), 0.0)

# %% [markdown]
# ### Task 2 <a id="task2"></a>  (0.5 points)
#
# To find the best split in the node we need to calculate the cost function. Denote:
# - `R` all the object in the node
# - `j` index of the feature selected for the split
# - `t` threshold
# - `R_l` and `R_r` objects in the left and right child nodes correspondingly
#
# We get the following cost function:
#
# $$
# Q(R, j, t) =\frac{|R_\ell|}{|R|}H(R_\ell) + \frac{|R_r|}{|R|}H(R_r) \to \min_{j, t},
# $$
#
# Implement the function `Q`, which should calculate value of the cost function for a given feature and threshold.

# %%
def Q(X, y, j, t):
    def R_r(selected_column, t, y):
        return len(y[selected_column > t]) * H(
            y[selected_column > t])

    def R_l(selected_column, t, y):
        return len(y[selected_column <= t]) * H(y[selected_column <= t])

    Q = 0
    selected_column = X[:, j]
    Q += R_l(selected_column, t, y) / len(y)
    Q += R_r(selected_column, t, y) / len(y)
    return Q

# %% [markdown]
# ### Task 3 <a id="task3"></a>  (2 points)
#
# Now, let's implement `MyDecisionTreeRegressor` class. More specifically, you need to implement the following methods:
#
# - `best_split`
# - `grow_tree`
# - `get_prediction`
#
# Also, please add `min_samples_leaf` parameter to your class
#
# Read docstrings for more details. Do not forget to use function `Q` implemented above, when finding the `best_split`

# %%
class Node(object):
    def __init__(self):
        self.right = None
        self.left = None
        self.threshold = None
        self.column = None
        self.depth = None
        self.is_terminal = False
        self.prediction = None

    def __repr__(self):
        if self.is_terminal:
            node_desc = 'Pred: {:.2f}'.format(self.prediction)
        else:
            node_desc = 'Col {}, t {:.2f}, Pred: {:.2f}'. \
            format(self.column, self.threshold, self.prediction)
        return node_desc

# %%
from sklearn.base import BaseEstimator, RegressorMixin
from sklearn.utils.validation import check_X_y, check_array, check_is_fitted

class MyDecisionTreeRegressor(RegressorMixin, BaseEstimator):
    def __init__(self, max_depth=3, min_samples_split=2, min_samples_leaf=1):
        self.max_depth = max_depth
        self.min_samples_split = min_samples_split
        self.min_samples_leaf = min_samples_leaf

    def best_split(self, X, y):
        best_split_column = None
        best_threshold = None
        best_cost = H(y)
        # семинар 7
        best_information_gain = -999

        for split_column in range(X.shape[1]):

            x_col = X[:, split_column]

            for i_x in range(0, len(x_col)):

                threshold = x_col[i_x]

                information_gain = best_cost - Q(X, y, split_column, threshold)

                if information_gain > best_information_gain:
                    best_split_column = split_column
                    best_threshold = threshold
                    best_information_gain = information_gain

        if best_information_gain == -999:
            return None, None, None, None, None, None

        x_col = X[:, best_split_column]
        X_left = X[x_col <= best_threshold, :]
        y_left = y[x_col <= best_threshold]
        X_right = X[x_col > best_threshold, :]
        y_right = y[x_col > best_threshold]

        return best_split_column, best_threshold, X_left, y_left, X_right, y_right

    def is_terminal(self, node, y):
        if node.depth >= self.max_depth:
            return True
        if len(y) < self.min_samples_split:
            return True
        return False

    def grow_tree(self, node, X, y):
        if self.is_terminal(node, y):
            node.is_terminal = True
            return
        # семинар 7
        if len(np.unique(y)) == 1:
            node.is_terminal = True
            return

        split_column, threshold, X_left, y_left, X_right, y_right = self.best_split(X, y)

        if split_column is None:
            node.is_terminal = True
            return

        # if len(X_left) < self.min_samples_leaf or len(X_right) < self.min_samples_leaf:
        #     node.is_terminal = True
        #     return

        if len(X_left) < self.min_samples_leaf or len(X_right) < self.min_samples_leaf:
            node.is_terminal = True
            return

        node.column = split_column
        node.threshold = threshold

        node.left = Node()
        node.left.depth = node.depth + 1
        node.left.prediction = np.mean(y_left)

        node.right = Node()
        node.right.depth = node.depth + 1
        node.right.prediction = np.mean(y_right)

        self.grow_tree(node.right, X_right, y_right)
        self.grow_tree(node.left, X_left, y_left)


    def fit(self, X, y):
        X, y = check_X_y(X, y, accept_sparse=False)
        self.is_fitted_ = True
        self.tree_ = Node()
        #  если указать, то в следующем задании установить макс глубину 1 не получиться, то надо менять либо на 0, либо оставлять тут один и подавать на вход глубину 2 или я не понял задание...
        self.tree_.depth = 1
        self.tree_.prediction = np.mean(y)

        # Grow the tree
        self.grow_tree(self.tree_, X, y)
        return self

    def get_prediction(self, node, x):
        if node.is_terminal:
            return node.prediction
        elif x[node.column] > node.threshold:
            return self.get_prediction(node.right, x)
        return self.get_prediction(node.left, x)

    def predict(self, X):
        X = check_array(X, accept_sparse=False)
        check_is_fitted(self, 'is_fitted_')

        # Get predictions
        y_predicted = []
        for x in X:
            y_curr = self.get_prediction(self.tree_, x)
            y_predicted.append(y_curr)
        return np.array(y_predicted)

# %%
# check yourself
from sklearn.utils.estimator_checks import check_estimator

check_estimator(MyDecisionTreeRegressor())
# Out:
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/estimator_checks.py:3608: FutureWarning: As of scikit-learn 0.23, estimators should expose a n_features_in_ attribute, unless the 'no_validation' tag is True. This attribute should be equal to the number of features passed to the fit method. An error will be raised from version 1.0 (renaming of 0.25) when calling check_estimator(). See SLEP010: https://scikit-learn-enhancement-proposals.readthedocs.io/en/latest/slep010/proposal.html
#   warnings.warn(
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/estimator_checks.py:3652: FutureWarning: As of scikit-learn 0.23, estimators should have a 'requires_y' tag set to the appropriate value. The default value of the tag is False. An error will be raised from version 1.0 when calling check_estimator() if the tag isn't properly set.
#   warnings.warn(warning_msg, FutureWarning)

# %% [markdown]
# ### Task 4 <a id="task4"></a>  (0.5 points)
#
# Load boston dataset and split it on the train ($75\%$) and test ($25\%$). Fit Decision Tree of depth 1 and make the following plot:
#
# - Scatter plot of the traning points (selected for split feature on the x-axis, target variable on the y-axis)
# - Fitted model

# %%
from sklearn.datasets import load_boston
from sklearn.model_selection import train_test_split

data = load_boston()
x = data.data
y = data.target

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.25,
                                                    random_state=987)
# Out:
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function load_boston is deprecated; `load_boston` is deprecated in 1.0 and will be removed in 1.2.
#
#     The Boston housing prices dataset has an ethical problem. You can refer to
#     the documentation of this function for further details.
#
#     The scikit-learn maintainers therefore strongly discourage the use of this
#     dataset unless the purpose of the code is to study and educate about
#     ethical issues in data science and machine learning.
#
#     In this special case, you can fetch the dataset from the original
#     source::
#
#         import pandas as pd
#         import numpy as np
#
#
#         data_url = "http://lib.stat.cmu.edu/datasets/boston"
#         raw_df = pd.read_csv(data_url, sep="\s+", skiprows=22, header=None)
#         data = np.hstack([raw_df.values[::2, :], raw_df.values[1::2, :2]])
#         target = raw_df.values[1::2, 2]
#
#     Alternative datasets include the California housing dataset (i.e.
#     :func:`~sklearn.datasets.fetch_california_housing`) and the Ames housing
#     dataset. You can load the datasets as follows::
#
#         from sklearn.datasets import fetch_california_housing
#         housing = fetch_california_housing()
#
#     for the California housing dataset and::
#
#         from sklearn.datasets import fetch_openml
#         housing = fetch_openml(name="house_prices", as_frame=True)
#
#     for the Ames housing dataset.
#
#   warnings.warn(msg, category=FutureWarning)

# %% [markdown]
# Глубину поставил 2, так как в классе у нас уже стоит глубина 1.

# %%
model = MyDecisionTreeRegressor(max_depth=2)
model.fit(x_train, y_train)
# Out:
# MyDecisionTreeRegressor(max_depth=2)

# %%
def plotting_scatter():
    plt.rcParams["figure.figsize"] = (20,10)
    plt.scatter(x_l_col, y_l, color='blue')
    plt.scatter(x_r_col, y_r, color='green')
    plt.scatter(x_l_col, predict_y_l, color='orange')
    plt.scatter(x_r_col, predict_y_r, color='red')
    plt.axvline(my_threshold, color='maroon')

# %%
model_pred = model.predict(x_train)

my_threshold = model.tree_.threshold

needed_column = x_train[:, model.tree_.column]

x_l, y_l = x_train[needed_column <= my_threshold], y_train[needed_column <= my_threshold]

x_r, y_r = x_train[needed_column > my_threshold], y_train[needed_column > my_threshold]
predict_y_l, predict_y_r = model_pred[needed_column <= my_threshold], model_pred[needed_column > my_threshold]

x_l_col = x_l[:, model.tree_.column]
x_r_col = x_r[:, model.tree_.column]

plotting_scatter()

# %% [markdown]
# Хотел построить дерево нашей модели как в 7 семинаре, но почему-то не вышло(

# %%
# from sklearn.tree import DecisionTreeRegressor
#
# plt.figure(figsize=(30, 30))
# from sklearn import tree
# model = DecisionTreeRegressor()
# model.fit(x_train, y_train)
#
# _ = tree.plot_tree(model,
#                    filled=True)
# plt.show()

# %% [markdown]
# ### Task 5 <a id="task5"></a>  (0.5 points)
#
# Keep working with boston dataset.
# - Use `GridSearchCV` to find the best hyperparameters among [`max_depth`, `min_samples_leaf`] on 5-Fold cross-validation
# - Train the model with the best set of hyperparameters on the whole train dataset.
# - Report `MAE` on test dataset and hyperparameters of the best estimator.

# %%
def mae(predict, target):
    y_true, predictions = np.array(target), np.array(predict)
    return np.mean(np.abs(y_true - predictions))

# %%
# %%time

'''
Лучший MAE: -3.059449461801575
CPU times: total: 1min 20s
Wall time: 1min 21s
'''



from sklearn.metrics import make_scorer
from sklearn.model_selection import GridSearchCV

# Если не делать make_scorer у меня кросс-вал час обучалась, не знаю с чем это связно, в ячейке ниже записаны те тайминги..

folds = 5
params = {'max_depth':range(1, 10, 2), 'min_samples_leaf':range(1, 10, 2)}
my_tree = MyDecisionTreeRegressor()
cross_val = GridSearchCV(my_tree, params, cv=folds, scoring=make_scorer(mae, greater_is_better=False), verbose=5)
cross_val.fit(x_train, y_train)
print(f'Лучшая глубина и min_samples_leaf: {cross_val.best_params_}')
print()
print()
print(f'Лучший MAE: {cross_val.best_score_}')
# Out:
# Fitting 5 folds for each of 25 candidates, totalling 125 fits
# [CV 1/5] END ..max_depth=1, min_samples_leaf=1;, score=-6.175 total time=   0.0s
# [CV 2/5] END ..max_depth=1, min_samples_leaf=1;, score=-6.548 total time=   0.0s
# [CV 3/5] END ..max_depth=1, min_samples_leaf=1;, score=-6.279 total time=   0.0s
# [CV 4/5] END ..max_depth=1, min_samples_leaf=1;, score=-6.867 total time=   0.0s
# [CV 5/5] END ..max_depth=1, min_samples_leaf=1;, score=-6.179 total time=   0.0s
# [CV 1/5] END ..max_depth=1, min_samples_leaf=3;, score=-6.175 total time=   0.0s
# [CV 2/5] END ..max_depth=1, min_samples_leaf=3;, score=-6.548 total time=   0.0s
# [CV 3/5] END ..max_depth=1, min_samples_leaf=3;, score=-6.279 total time=   0.0s
# [CV 4/5] END ..max_depth=1, min_samples_leaf=3;, score=-6.867 total time=   0.0s
# [CV 5/5] END ..max_depth=1, min_samples_leaf=3;, score=-6.179 total time=   0.0s
# [CV 1/5] END ..max_depth=1, min_samples_leaf=5;, score=-6.175 total time=   0.0s
# [CV 2/5] END ..max_depth=1, min_samples_leaf=5;, score=-6.548 total time=   0.0s
# [CV 3/5] END ..max_depth=1, min_samples_leaf=5;, score=-6.279 total time=   0.0s
# [CV 4/5] END ..max_depth=1, min_samples_leaf=5;, score=-6.867 total time=   0.0s
# [CV 5/5] END ..max_depth=1, min_samples_leaf=5;, score=-6.179 total time=   0.0s
# [CV 1/5] END ..max_depth=1, min_samples_leaf=7;, score=-6.175 total time=   0.0s
# [CV 2/5] END ..max_depth=1, min_samples_leaf=7;, score=-6.548 total time=   0.0s
# [CV 3/5] END ..max_depth=1, min_samples_leaf=7;, score=-6.279 total time=   0.0s
# [CV 4/5] END ..max_depth=1, min_samples_leaf=7;, score=-6.867 total time=   0.0s
# [CV 5/5] END ..max_depth=1, min_samples_leaf=7;, score=-6.179 total time=   0.0s
# [CV 1/5] END ..max_depth=1, min_samples_leaf=9;, score=-6.175 total time=   0.0s
# [CV 2/5] END ..max_depth=1, min_samples_leaf=9;, score=-6.548 total time=   0.0s
# [CV 3/5] END ..max_depth=1, min_samples_leaf=9;, score=-6.279 total time=   0.0s
# [CV 4/5] END ..max_depth=1, min_samples_leaf=9;, score=-6.867 total time=   0.0s
# [CV 5/5] END ..max_depth=1, min_samples_leaf=9;, score=-6.179 total time=   0.0s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=1;, score=-3.928 total time=   0.3s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=1;, score=-4.011 total time=   0.3s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=1;, score=-4.308 total time=   0.3s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=1;, score=-3.923 total time=   0.3s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=1;, score=-3.546 total time=   0.3s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=3;, score=-3.928 total time=   0.3s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=3;, score=-4.011 total time=   0.4s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=3;, score=-4.308 total time=   0.3s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=3;, score=-3.923 total time=   0.3s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=3;, score=-3.546 total time=   0.3s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=5;, score=-3.928 total time=   0.3s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=5;, score=-4.011 total time=   0.3s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=5;, score=-4.308 total time=   0.3s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=5;, score=-3.923 total time=   0.3s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=5;, score=-3.546 total time=   0.3s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=7;, score=-3.928 total time=   0.3s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=7;, score=-4.011 total time=   0.3s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=7;, score=-4.308 total time=   0.3s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=7;, score=-3.923 total time=   0.3s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=7;, score=-3.546 total time=   0.3s
# [CV 1/5] END ..max_depth=3, min_samples_leaf=9;, score=-3.928 total time=   0.3s
# [CV 2/5] END ..max_depth=3, min_samples_leaf=9;, score=-4.011 total time=   0.3s
# [CV 3/5] END ..max_depth=3, min_samples_leaf=9;, score=-4.308 total time=   0.3s
# [CV 4/5] END ..max_depth=3, min_samples_leaf=9;, score=-3.923 total time=   0.3s
# [CV 5/5] END ..max_depth=3, min_samples_leaf=9;, score=-3.546 total time=   0.3s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=1;, score=-2.735 total time=   0.6s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=1;, score=-2.893 total time=   0.9s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=1;, score=-3.804 total time=   0.8s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=1;, score=-3.422 total time=   0.8s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=1;, score=-2.444 total time=   0.8s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=3;, score=-2.707 total time=   0.8s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=3;, score=-2.824 total time=   0.8s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=3;, score=-3.766 total time=   0.7s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=3;, score=-3.607 total time=   0.5s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=3;, score=-2.503 total time=   0.6s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=5;, score=-3.854 total time=   0.5s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=5;, score=-3.684 total time=   0.5s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=5;, score=-4.035 total time=   0.5s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=5;, score=-3.630 total time=   0.5s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=5;, score=-2.514 total time=   0.6s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=7;, score=-3.848 total time=   0.5s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=7;, score=-3.680 total time=   0.5s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=7;, score=-4.035 total time=   0.5s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=7;, score=-3.613 total time=   0.5s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=7;, score=-2.514 total time=   0.6s
# [CV 1/5] END ..max_depth=5, min_samples_leaf=9;, score=-3.848 total time=   0.5s
# [CV 2/5] END ..max_depth=5, min_samples_leaf=9;, score=-3.680 total time=   0.5s
# [CV 3/5] END ..max_depth=5, min_samples_leaf=9;, score=-4.035 total time=   0.5s
# [CV 4/5] END ..max_depth=5, min_samples_leaf=9;, score=-3.613 total time=   0.5s
# [CV 5/5] END ..max_depth=5, min_samples_leaf=9;, score=-2.720 total time=   0.6s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=1;, score=-3.114 total time=   0.8s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=1;, score=-3.174 total time=   0.8s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=1;, score=-3.397 total time=   0.8s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=1;, score=-3.117 total time=   0.8s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=1;, score=-2.620 total time=   0.9s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=3;, score=-2.666 total time=   0.8s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=3;, score=-2.958 total time=   0.8s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=3;, score=-3.652 total time=   0.8s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=3;, score=-3.565 total time=   0.6s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=3;, score=-2.650 total time=   0.7s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=5;, score=-3.937 total time=   0.6s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=5;, score=-3.646 total time=   0.5s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=5;, score=-3.961 total time=   0.5s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=5;, score=-3.657 total time=   0.5s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=5;, score=-2.498 total time=   0.7s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=7;, score=-4.006 total time=   0.6s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=7;, score=-3.598 total time=   0.5s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=7;, score=-3.961 total time=   0.5s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=7;, score=-3.640 total time=   0.5s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=7;, score=-2.447 total time=   0.7s
# [CV 1/5] END ..max_depth=7, min_samples_leaf=9;, score=-4.006 total time=   0.6s
# [CV 2/5] END ..max_depth=7, min_samples_leaf=9;, score=-3.680 total time=   0.5s
# [CV 3/5] END ..max_depth=7, min_samples_leaf=9;, score=-3.961 total time=   0.5s
# [CV 4/5] END ..max_depth=7, min_samples_leaf=9;, score=-3.613 total time=   0.5s
# [CV 5/5] END ..max_depth=7, min_samples_leaf=9;, score=-2.653 total time=   0.6s
# [CV 1/5] END ..max_depth=9, min_samples_leaf=1;, score=-3.381 total time=   1.0s
# [CV 2/5] END ..max_depth=9, min_samples_leaf=1;, score=-3.133 total time=   1.1s
# [CV 3/5] END ..max_depth=9, min_samples_leaf=1;, score=-3.244 total time=   1.1s
# [CV 4/5] END ..max_depth=9, min_samples_leaf=1;, score=-3.270 total time=   1.1s
# [CV 5/5] END ..max_depth=9, min_samples_leaf=1;, score=-2.540 total time=   1.1s
# [CV 1/5] END ..max_depth=9, min_samples_leaf=3;, score=-2.732 total time=   0.8s
# [CV 2/5] END ..max_depth=9, min_samples_leaf=3;, score=-2.932 total time=   0.8s
# [CV 3/5] END ..max_depth=9, min_samples_leaf=3;, score=-3.596 total time=   0.8s
# [CV 4/5] END ..max_depth=9, min_samples_leaf=3;, score=-3.714 total time=   0.6s
# [CV 5/5] END ..max_depth=9, min_samples_leaf=3;, score=-2.680 total time=   0.7s
# [CV 1/5] END ..max_depth=9, min_samples_leaf=5;, score=-3.937 total time=   0.6s
# [CV 2/5] END ..max_depth=9, min_samples_leaf=5;, score=-3.646 total time=   0.5s
# [CV 3/5] END ..max_depth=9, min_samples_leaf=5;, score=-3.961 total time=   0.5s
# [CV 4/5] END ..max_depth=9, min_samples_leaf=5;, score=-3.657 total time=   0.6s
# [CV 5/5] END ..max_depth=9, min_samples_leaf=5;, score=-2.528 total time=   0.7s
# [CV 1/5] END ..max_depth=9, min_samples_leaf=7;, score=-4.006 total time=   0.6s
# [CV 2/5] END ..max_depth=9, min_samples_leaf=7;, score=-3.598 total time=   0.5s
# [CV 3/5] END ..max_depth=9, min_samples_leaf=7;, score=-3.961 total time=   0.5s
# [CV 4/5] END ..max_depth=9, min_samples_leaf=7;, score=-3.640 total time=   0.5s
# [CV 5/5] END ..max_depth=9, min_samples_leaf=7;, score=-2.447 total time=   0.7s
# [CV 1/5] END ..max_depth=9, min_samples_leaf=9;, score=-4.006 total time=   0.6s
# [CV 2/5] END ..max_depth=9, min_samples_leaf=9;, score=-3.680 total time=   0.5s
# [CV 3/5] END ..max_depth=9, min_samples_leaf=9;, score=-3.961 total time=   0.5s
# [CV 4/5] END ..max_depth=9, min_samples_leaf=9;, score=-3.613 total time=   0.5s
# [CV 5/5] END ..max_depth=9, min_samples_leaf=9;, score=-2.653 total time=   0.7s
# Лучшая глубина и min_samples_leaf: {'max_depth': 5, 'min_samples_leaf': 1}
#
#
# Лучший MAE: -3.059449461801575
# CPU times: user 56.1 s, sys: 418 ms, total: 56.5 s
# Wall time: 57.9 s

# %% [markdown]
# Лучшие параметры: {'max_depth': 7, 'min_samples_leaf': 2}
#
# Лучший счет: -4.477892111095516
#
# CPU times: total: 1h 2min 35s
# Wall time: 1h 2min 56s

# %%
model = MyDecisionTreeRegressor(max_depth=5, min_samples_leaf=1)
model.fit(x_train, y_train)
predicts = model.predict(x_test)
print('Final MAE:', mae(predicts, y_test))
# Out:
# Final MAE: 3.137451532719748

# %% [markdown]
# ### Task 6 <a id="task6"></a>  (2 points)
#
# Recall definition of bias and variance:
# $$
# \text{Bias}^2 = \mathbb{E}_{p(x, y)} \left[  (f(x) - \mathbb{E}_{\mathbb{X}}a_{\mathbb{X}}(x))^2 \right] \\
# \text{Variance} = \mathbb{E}_{p(x, y)} \left[  \mathbb{V}_{\mathbb{X}}( a_{\mathbb{X}}(x))  \right]
# $$
#
# We wil now use use the following algorithm to estimate bias and variance:
#
# 1. Use bootsrap to create `n_iter` samples from the original dataset: $X_1, \dots, X_{n_iter}$
# 2. For each bootstrapped sample define out-of-bag (OOB) sample $Z_1, \dots, Z_{n_iter}$, which contain all the observations, which did not appear in the corresponding boostraped sample
# 3. Fit the model on $X_i$s and compute predictions on $Z_i$s
# 4. For a given *object* $n$:
#      - bias^2: squared difference between true value $y_n$ and average prediction (average over the algorithms, for which $n$ was in OOB)
#      - variance: variance of the prediction (predictions of the algorithms, for which $n$ was in OOB)
# 5. Average bias^2 and variance over all the points
#
# **Implement `get_bias_variance` function, using the algorithm above**
#
# *Note:*  You can only use 1 loop (for bootsrap iterations). All other operations should be vectorized.

# %%
def creating_nan_array(x):
    arr = np.empty(len(x))
    arr[:] = np.NaN
    return arr

# %%
def first_step(x):
    return np.random.choice(len(x), len(x))

# %%
def second_step(bootsrap, x):
    return np.array(list(set(np.arange(len(x))) - set(bootsrap)))

# %%
def third_step(bootsrap, estimator, out_of_bag, x, y):
    estimator.fit(x[bootsrap, :], y[bootsrap])
    predicted = estimator.predict(x[out_of_bag, :])
    return predicted

# %%
def concate_numpy_arr(out_of_bag, predicted, total_arr_pred, x):
    my_arr_nan = creating_nan_array(x)
    np.put(my_arr_nan, out_of_bag, predicted)
    total_arr_pred = np.column_stack((total_arr_pred, my_arr_nan))
    return total_arr_pred

# %%
def forth_step(total_arr_pred, y):
    bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
    var = np.nanvar(total_arr_pred, axis=1)
    return bias, var

# %%
def fifth_step(bias, var):
    return np.nanmean(bias), np.nanmean(var)

# %% [markdown]
# Идея в том, чтобы каждый раз собирать матрицу результатов в каждой итерации, чтобы подсчитать дисперсию сразу на всем многомерном массиве.

# %%
def get_bias_variance(estimator, x, y, n_iter):
    np.random.seed(987)
    # total_arr_pred = np.array([np.NaN for element in range(len(x))])

    total_arr_pred = creating_nan_array(x)
    for i in range(0, n_iter):
        bootsrap = first_step(x)
        out_of_bag = second_step(bootsrap, x)
        predicted = third_step(bootsrap, estimator, out_of_bag, x, y)
        # my_arr_nan = np.array([np.NaN for element in range(len(x))])
        total_arr_pred = concate_numpy_arr(out_of_bag, predicted, total_arr_pred, x)

    bias, var = forth_step(total_arr_pred, y)
    return fifth_step(bias, var)

# %%
estimator = MyDecisionTreeRegressor(max_depth=8, min_samples_split=15)

get_bias_variance(estimator, x_train, y_train, 10)
# Out:
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# (13.26113341498087, 8.961578091683037)

# %% [markdown]
# ### Task 7 <a id="task7"></a>  (0.5 points)
#
# Compute bias and variance for the trees with different min_samples_split. Plot how bias and variance change as min_samples_split increases.
#
# Comment on what you observe, how does your result correspond to theory?

# %%
np.random.seed(987)
plt.rcParams['figure.figsize'] = (15, 10)

bias_list = np.empty(len([1, 5, 10, 15, 30, 35, 45, 60]))
var_list = np.empty(len([1, 5, 10, 15, 30, 35, 45, 60]))
for index, min_sample in enumerate([1, 5, 10, 15, 30, 35, 45, 60]):
    model = MyDecisionTreeRegressor(max_depth=20, min_samples_split=min_sample)
    bias, variance = get_bias_variance(model, x_train, y_train, 10)
    bias_list[index] = bias
    var_list[index] = variance
plt.plot([1, 5, 10, 15, 30, 35, 45, 60], bias_list, label='bias')
plt.plot([1, 5, 10, 15, 30, 35, 45, 60], var_list, label='variance')
plt.legend()
plt.show()
# Out:
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)

# %% [markdown]
# ```Если опираться на теорию, что при увеличении min_samples_split дерево обучается хуже с каждым инкрементом вверх, поэтому дисперсия будет меньше, то на графике это отчетливо видно - дисперсия падает, при чем если бы мы взяли глубину деревьев еще больше - она упала бы еще сильнее. А вот биас наоборот растет, так как мы не даем дереву переобучаться.```

# %% [markdown]
# ### Task 8 <a id="task8"></a>  (0.5 points)
#
# Let's try to reduce variance with bagging. Use `sklearn.ensemble.BaggingRegressor` to get an ensemble and compute its bias and variance.
#
# Answer the following questions:
#  - How bagging should affect bias and variance in theory?
#  - How bias and variance change (if they change) compared to an individual tree in you experiments?
#  - Do your results align with the theory? Why?

# %%
from sklearn.ensemble import BaggingRegressor


model = BaggingRegressor(base_estimator=MyDecisionTreeRegressor(max_depth=8, min_samples_split=15),
                         n_estimators=60, random_state=987, n_jobs=-1)
get_bias_variance(model, x_train, y_train, 10)
# Out:
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:2: RuntimeWarning: Mean of empty slice
#   bias = np.square(y - np.nanmean(total_arr_pred, axis=1))
# /var/folders/47/4y0ypxc92dz4v_h0jyn8jqpw0000gn/T/ipykernel_8070/3955871046.py:3: RuntimeWarning: Degrees of freedom <= 0 for slice.
#   var = np.nanvar(total_arr_pred, axis=1)
# (12.083306151976949, 1.75115492437668)

# %% [markdown]
# ```Bagging усредняет кол-во деревьев, отчего долженно упасть значение дисперсии - так и произошло, а вот биас может упасть или вырасти, однако он упал, но совсем на чуть-чуть.```

# %% [markdown]
# # Part 2. More Ensembles

# %% [markdown]
# In this part we will be working with [Thyroid Disease Data Set](https://archive.ics.uci.edu/ml/datasets/thyroid+disease) to solve a classification task.

# %%
from sklearn.preprocessing import LabelEncoder

df = pd.read_csv('../datasets/thyroid_disease.csv')

le = LabelEncoder()
y = le.fit_transform(df['Class'])
X = df.drop('Class', axis=1)
X.head(5)
# Out:
#     age sex on_thyroxine query_on_thyroxine on_antithyroid_medication sick  \
# 0  41.0   F            f                  f                         f    f
# 1  23.0   F            f                  f                         f    f
# 2  46.0   M            f                  f                         f    f
# 3  70.0   F            t                  f                         f    f
# 4  70.0   F            f                  f                         f    f
#
#   pregnant thyroid_surgery I131_treatment query_hypothyroid  ...   T3  \
# 0        f               f              f                 f  ...  2.5
# 1        f               f              f                 f  ...  2.0
# 2        f               f              f                 f  ...  NaN
# 3        f               f              f                 f  ...  1.9
# 4        f               f              f                 f  ...  1.2
#
#   TT4_measured    TT4 T4U_measured   T4U FTI_measured    FTI  TBG_measured  \
# 0            t  125.0            t  1.14            t  109.0             f
# 1            t  102.0            f   NaN            f    NaN             f
# 2            t  109.0            t  0.91            t  120.0             f
# 3            t  175.0            f   NaN            f    NaN             f
# 4            t   61.0            t  0.87            t   70.0             f
#
#   TBG  referral_source
# 0 NaN             SVHC
# 1 NaN            other
# 2 NaN            other
# 3 NaN            other
# 4 NaN              SVI
#
# [5 rows x 29 columns]

# %% [markdown]
# ### Task 1 <a id="task2_1"></a> (1 point)
#
# Let's start with data preprocessing.
#
# 0. Drop columns, which are not usefull (e.g. a lot of missing values). Motivate your choice.
# 1. Split dataset into train and test
# 2. You've probably noticed that we have both categorical and numerical columns. Here is what you need to do with them:
#     - Categorical: Fill missing values and apply one-hot-encoding
#     - Numeric: Fill missing values
#
# Use `ColumnTranformer` to define a single transformer for all the columns in the dataset. It takes as input a list of tuples
#
# ```
# ColumnTransformer([
#     ('name1', transform1, column_names1),
#     ('name2', transform2, column_names2)
# ])
# ```
#
# Pay attention to an argument `remainder='passthrough'`. [Here](https://scikit-learn.org/stable/modules/compose.html#column-transformer) you can find some examples of how to use column transformer.
#
# Since we want to apply 2 transformations to categorical feature, it is very convenient to combine them into a `Pipeline`:
#
# ```
# double_tranform = make_pipeline(
#                         transform_1,
#                         transform_2
#                         )
# ```
#
# P.S. Choose your favourite way to fill missing values.
#
# *Hint* Categorical column usually have `dtype = 'object'`. This may help to obtain list of categorical and numerical columns on the dataset.

# %%
def data_info(data):
    data.info()
    display(data.head())
    display(data.describe())

# %% [markdown]
# Вообще стараться удалить все столбца с np.nan плохая идея, так что удалить столбцы, где пропуски составляют больше 10 процентов, главное - удалится столбец, полностью состоящий из np.nan.

# %%
# data_info(df)
display(X.isna().mean())
X = X.drop(columns=X.columns[X.isna().mean() > 3772.0 * 0.1 / 3772.0])
X.info()
# Out:
# age                          0.000265
# sex                          0.039767
# on_thyroxine                 0.000000
# query_on_thyroxine           0.000000
# on_antithyroid_medication    0.000000
# sick                         0.000000
# pregnant                     0.000000
# thyroid_surgery              0.000000
# I131_treatment               0.000000
# query_hypothyroid            0.000000
# query_hyperthyroid           0.000000
# lithium                      0.000000
# goitre                       0.000000
# tumor                        0.000000
# hypopituitary                0.000000
# psych                        0.000000
# TSH_measured                 0.000000
# TSH                          0.097826
# T3_measured                  0.000000
# T3                           0.203871
# TT4_measured                 0.000000
# TT4                          0.061241
# T4U_measured                 0.000000
# T4U                          0.102598
# FTI_measured                 0.000000
# FTI                          0.102068
# TBG_measured                 0.000000
# TBG                          1.000000
# referral_source              0.000000
# dtype: float64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3772 entries, 0 to 3771
# Data columns (total 25 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   age                        3771 non-null   float64
#  1   sex                        3622 non-null   object
#  2   on_thyroxine               3772 non-null   object
#  3   query_on_thyroxine         3772 non-null   object
#  4   on_antithyroid_medication  3772 non-null   object
#  5   sick                       3772 non-null   object
#  6   pregnant                   3772 non-null   object
#  7   thyroid_surgery            3772 non-null   object
#  8   I131_treatment             3772 non-null   object
#  9   query_hypothyroid          3772 non-null   object
#  10  query_hyperthyroid         3772 non-null   object
#  11  lithium                    3772 non-null   object
#  12  goitre                     3772 non-null   object
#  13  tumor                      3772 non-null   object
#  14  hypopituitary              3772 non-null   object
#  15  psych                      3772 non-null   object
#  16  TSH_measured               3772 non-null   object
#  17  TSH                        3403 non-null   float64
#  18  T3_measured                3772 non-null   object
#  19  TT4_measured               3772 non-null   object
#  20  TT4                        3541 non-null   float64
#  21  T4U_measured               3772 non-null   object
#  22  FTI_measured               3772 non-null   object
#  23  TBG_measured               3772 non-null   object
#  24  referral_source            3772 non-null   object
# dtypes: float64(3), object(22)
# memory usage: 736.8+ KB

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=987)

# %%
from sklearn.preprocessing import OneHotEncoder
from sklearn.impute import SimpleImputer
from sklearn.pipeline import make_pipeline
from sklearn.compose import ColumnTransformer

numeric = [column for column in X.columns if X[column].dtype != 'object']
print(numeric)
categorial = [column for column in X.columns if column not in numeric]
print(categorial)

categorial = X.select_dtypes(include="object").columns
numeric = X.select_dtypes(exclude="object").columns

column_transformer = ColumnTransformer(transformers=[
    ('categorial', make_pipeline(SimpleImputer(strategy='most_frequent'),
                                  OneHotEncoder(drop='if_binary')),
                                 categorial),
    ('numeric', SimpleImputer(strategy='median'),
     numeric)], remainder='passthrough')

X_train = column_transformer.fit_transform(X_train)
X_test = column_transformer.transform(X_test)
# Out:
# ['age', 'TSH', 'TT4']
# ['sex', 'on_thyroxine', 'query_on_thyroxine', 'on_antithyroid_medication', 'sick', 'pregnant', 'thyroid_surgery', 'I131_treatment', 'query_hypothyroid', 'query_hyperthyroid', 'lithium', 'goitre', 'tumor', 'hypopituitary', 'psych', 'TSH_measured', 'T3_measured', 'TT4_measured', 'T4U_measured', 'FTI_measured', 'TBG_measured', 'referral_source']

# %%
X_train
# Out:
# array([[  0.  ,   0.  ,   0.  , ...,  76.  ,   0.9 , 105.  ],
#        [  1.  ,   1.  ,   1.  , ...,  52.  ,   1.4 ,  99.  ],
#        [  1.  ,   0.  ,   0.  , ...,  69.  ,   1.1 ,  99.  ],
#        ...,
#        [  0.  ,   0.  ,   0.  , ...,  53.  ,   0.83, 193.  ],
#        [  0.  ,   1.  ,   0.  , ...,  64.  ,   7.7 , 111.  ],
#        [  0.  ,   0.  ,   0.  , ...,  76.  ,  39.  ,  83.  ]])

# %% [markdown]
# ### Task 2 <a id="task2_2"></a> (0.7 points)
#
# Fit and compare 5 different models (use sklearn): Gradient Boosting, Random Forest, Decision Tree, SVM, Logitics Regression
#
# * Choose one classification metric and justify your choice .
# * Compare the models using score on cross validation. Mind the class balance when choosing the cross validation. (You can read more about different CV strategies [here](https://scikit-learn.org/stable/modules/cross_validation.html#stratified-k-fold))
# * Which model has the best performance? Which models overfit or underfit?

# %%
from sklearn.metrics import f1_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import GradientBoostingClassifier, RandomForestClassifier
from sklearn.model_selection import StratifiedKFold, KFold
from sklearn.model_selection import cross_val_score


gradient = GradientBoostingClassifier(random_state=987)
forest = RandomForestClassifier(random_state=987)
tree = DecisionTreeClassifier(random_state=987)
svm = SVC(random_state=987)
logistic = LogisticRegression(random_state=987)
f1_list = list()


models = [GradientBoostingClassifier(), DecisionTreeClassifier(), SVC(), LogisticRegression(), RandomForestClassifier()]

folds = StratifiedKFold(n_splits=5) #default cv=5

for index, model in enumerate(models):
    scores = cross_val_score(model, X_train, y_train, cv=folds, scoring='f1', n_jobs=-1)
    model.fit(X_train, y_train)
    final_score = sum(scores) / len(scores)
    print(f'Средняя оценка качества модели {model} на кросс-валидации:', final_score)
    print(f'Средняя оценка качества модели {model} на тестовой выборке:', f1_score(y_true=y_test, y_pred=model.predict(X_test)))
# Out:
# Средняя оценка качества модели GradientBoostingClassifier() на кросс-валидации: 0.20503758815779274
# Средняя оценка качества модели GradientBoostingClassifier() на тестовой выборке: 0.30303030303030304
# Средняя оценка качества модели DecisionTreeClassifier() на кросс-валидации: 0.22161162997887823
# Средняя оценка качества модели DecisionTreeClassifier() на тестовой выборке: 0.25862068965517243
# Средняя оценка качества модели SVC() на кросс-валидации: 0.0
# Средняя оценка качества модели SVC() на тестовой выборке: 0.0
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/sklearn/linear_model/_logistic.py:814: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# Средняя оценка качества модели LogisticRegression() на кросс-валидации: 0.03187803187803188
# Средняя оценка качества модели LogisticRegression() на тестовой выборке: 0.0
# Средняя оценка качества модели RandomForestClassifier() на кросс-валидации: 0.21855054915026484
# Средняя оценка качества модели RandomForestClassifier() на тестовой выборке: 0.26865671641791045

# %% [markdown]
# ```По данным метрик можно сказать, что Дерево переобучилось, так как показала результат ниже, чем на кросс-валидации. Модели SVM вообще имеют абсолютные нули, значит либо точность либо полнота были равны 0, что не есть хорошо. С лучшей стороны себя показал случайный лес на тестовой выборке.```

# %% [markdown]
# ### Task 3 <a id="task2_3"></a> (0.5 points)
#
# More Gradient Boosting. You will have to implement one of the three popular boosting implementations (xgboost, lightgbm, catboost). Select hyperparameters (number of trees, learning rate, depth) on cross-validation and compare with the methods from the previous task.
#
# To get method that you have to implement, run cell below and input your name in Russian (for example, if you input Андрей, you will see that user with this name should implement xgboost)

# %%
def assign_method():
    name = input()
    methods = ['xgboost', 'lightgbm', 'catboost']
    idx = sum([ord(x) for x in list(name)]) % 3
    print('Реализуйте', methods[idx])


assign_method()
# Out:
# Реализуйте xgboost

# %%
# !pip install catboost
# Out:
# Requirement already satisfied: catboost in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (1.0.6)
# Requirement already satisfied: scipy in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.7.3)
# Requirement already satisfied: plotly in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from catboost) (5.9.0)
# Requirement already satisfied: graphviz in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from catboost) (0.20.1)
# Requirement already satisfied: numpy>=1.16.0 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.21.5)
# Requirement already satisfied: pandas>=0.24.0 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.4.4)
# Requirement already satisfied: six in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from catboost) (1.16.0)
# Requirement already satisfied: matplotlib in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from catboost) (3.6.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from pandas>=0.24.0->catboost) (2022.1)
# Requirement already satisfied: cycler>=0.10 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (21.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (1.4.2)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (1.0.5)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (4.25.0)
# Requirement already satisfied: pillow>=6.2.0 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (9.2.0)
# Requirement already satisfied: pyparsing>=2.2.1 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from matplotlib->catboost) (3.0.9)
# Requirement already satisfied: tenacity>=6.2.0 in /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages (from plotly->catboost) (8.0.1)

# %%
from catboost import CatBoostClassifier
from sklearn.model_selection import GridSearchCV

parameters = {'learning_rate': [0.1, 0.15, 0.25, 0.5, 0.8, 1],
              'depth': range(1, 20, 2),
              'num_trees': [2, 4, 6, 12, 20, 25]}

cat_boost = CatBoostClassifier()
cross_vall = GridSearchCV(cat_boost, parameters, scoring='f1', cv=5, verbose=15, n_jobs=-1)
cross_vall.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 360 candidates, totalling 1800 fits
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/trupolog/opt/anaconda3/lib/python3.9/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# [CV 2/5; 1/360] START depth=1, learning_rate=0.1, num_trees=2...................
# 0:	learn: 0.5836744	total: 63.2ms	remaining: 63.2ms
# 1:	learn: 0.4965348	total: 63.5ms	remaining: 0us
# [CV 2/5; 1/360] END depth=1, learning_rate=0.1, num_trees=2;, score=0.000 total time=   0.1s
# [CV 4/5; 3/360] START depth=1, learning_rate=0.1, num_trees=6...................
# 0:	learn: 0.5775607	total: 485us	remaining: 2.43ms
# 1:	learn: 0.4921497	total: 1.07ms	remaining: 2.13ms
# 2:	learn: 0.4311019	total: 1.5ms	remaining: 1.5ms
# 3:	learn: 0.3848912	total: 1.81ms	remaining: 906us
# 4:	learn: 0.3492192	total: 2.15ms	remaining: 429us
# 5:	learn: 0.3080281	total: 2.97ms	remaining: 0us
# [CV 4/5; 3/360] END depth=1, learning_rate=0.1, num_trees=6;, score=0.000 total time=   0.0s
# [CV 3/5; 5/360] START depth=1, learning_rate=0.1, num_trees=20..................
# 0:	learn: 0.5774730	total: 431us	remaining: 8.2ms
# 1:	learn: 0.4932111	total: 733us	remaining: 6.6ms
# 2:	learn: 0.4136574	total: 1.03ms	remaining: 5.84ms
# 3:	learn: 0.3701128	total: 1.35ms	remaining: 5.41ms
# 4:	learn: 0.3370474	total: 1.67ms	remaining: 5.02ms
# 5:	learn: 0.3113300	total: 1.95ms	remaining: 4.54ms
# 6:	learn: 0.2851435	total: 2.23ms	remaining: 4.13ms
# 7:	learn: 0.2710585	total: 2.55ms	remaining: 3.83ms
# 8:	learn: 0.2578663	total: 2.84ms	remaining: 3.47ms
# 9:	learn: 0.2494787	total: 3.11ms	remaining: 3.11ms
# 10:	learn: 0.2431140	total: 3.5ms	remaining: 2.87ms
# 11:	learn: 0.2321179	total: 3.8ms	remaining: 2.53ms
# 12:	learn: 0.2260771	total: 4.1ms	remaining: 2.21ms
# 13:	learn: 0.2190579	total: 4.46ms	remaining: 1.91ms
# 14:	learn: 0.2160379	total: 4.78ms	remaining: 1.59ms
# 15:	learn: 0.2114026	total: 5.17ms	remaining: 1.29ms
# 16:	learn: 0.2088435	total: 7.23ms	remaining: 1.28ms
# 17:	learn: 0.2070560	total: 7.58ms	remaining: 842us
# 18:	learn: 0.2048634	total: 7.93ms	remaining: 417us
# 19:	learn: 0.2024383	total: 8.22ms	remaining: 0us
# [CV 3/5; 5/360] END depth=1, learning_rate=0.1, num_trees=20;, score=0.000 total time=   0.1s
# [CV 5/5; 7/360] START depth=1, learning_rate=0.15, num_trees=2..................
# 0:	learn: 0.5360075	total: 376us	remaining: 376us
# 1:	learn: 0.4064610	total: 665us	remaining: 0us
# [CV 5/5; 7/360] END depth=1, learning_rate=0.15, num_trees=2;, score=0.000 total time=   0.0s
# [CV 4/5; 9/360] START depth=1, learning_rate=0.15, num_trees=6..................
# 0:	learn: 0.5278537	total: 404us	remaining: 2.02ms
# 1:	learn: 0.4229212	total: 679us	remaining: 1.36ms
# 2:	learn: 0.3512461	total: 969us	remaining: 969us
# 3:	learn: 0.3108137	total: 1.26ms	remaining: 628us
# 4:	learn: 0.2840123	total: 1.58ms	remaining: 316us
# 5:	learn: 0.2503470	total: 1.95ms	remaining: 0us
# [CV 4/5; 9/360] END depth=1, learning_rate=0.15, num_trees=6;, score=0.000 total time=   0.0s
# [CV 4/5; 11/360] START depth=1, learning_rate=0.15, num_trees=20................
# 0:	learn: 0.5278537	total: 720us	remaining: 13.7ms
# 1:	learn: 0.4229212	total: 1.02ms	remaining: 9.18ms
# 2:	learn: 0.3512461	total: 1.33ms	remaining: 7.56ms
# 3:	learn: 0.3108137	total: 1.76ms	remaining: 7.06ms
# 4:	learn: 0.2840123	total: 2.08ms	remaining: 6.25ms
# 5:	learn: 0.2503470	total: 2.38ms	remaining: 5.55ms
# 6:	learn: 0.2392433	total: 2.65ms	remaining: 4.93ms
# 7:	learn: 0.2290496	total: 2.92ms	remaining: 4.39ms
# 8:	learn: 0.2180565	total: 3.34ms	remaining: 4.08ms
# 9:	learn: 0.2111351	total: 3.64ms	remaining: 3.64ms
# 10:	learn: 0.2045591	total: 3.94ms	remaining: 3.23ms
# 11:	learn: 0.2018284	total: 4.23ms	remaining: 2.82ms
# 12:	learn: 0.1987746	total: 4.56ms	remaining: 2.46ms
# 13:	learn: 0.1970265	total: 4.86ms	remaining: 2.08ms
# 14:	learn: 0.1939547	total: 5.16ms	remaining: 1.72ms
# 15:	learn: 0.1924349	total: 5.42ms	remaining: 1.36ms
# 16:	learn: 0.1914829	total: 5.7ms	remaining: 1ms
# 17:	learn: 0.1896241	total: 5.97ms	remaining: 663us
# 18:	learn: 0.1886379	total: 6.25ms	remaining: 328us
# 19:	learn: 0.1875287	total: 6.52ms	remaining: 0us
# [CV 4/5; 11/360] END depth=1, learning_rate=0.15, num_trees=20;, score=0.000 total time=   0.0s
# [CV 5/5; 13/360] START depth=1, learning_rate=0.25, num_trees=2.................
# 0:	learn: 0.4535309	total: 420us	remaining: 420us
# 1:	learn: 0.3090112	total: 709us	remaining: 0us
# [CV 5/5; 13/360] END depth=1, learning_rate=0.25, num_trees=2;, score=0.000 total time=   0.0s
# [CV 1/5; 14/360] START depth=1, learning_rate=0.25, num_trees=4.................
# 0:	learn: 0.4405323	total: 461us	remaining: 1.39ms
# 1:	learn: 0.3300695	total: 775us	remaining: 775us
# 2:	learn: 0.2743295	total: 1.14ms	remaining: 379us
# 3:	learn: 0.2324890	total: 1.44ms	remaining: 0us
# [CV 1/5; 14/360] END depth=1, learning_rate=0.25, num_trees=4;, score=0.000 total time=   0.0s
# 6:	learn: 0.1855901	total: 2.14ms	remaining: 1.53ms
# 7:	learn: 0.1829606	total: 2.44ms	remaining: 1.22ms
# 8:	learn: 0.1818173	total: 2.77ms	remaining: 921us
# 9:	learn: 0.1809522	total: 3.08ms	remaining: 616us
# 10:	learn: 0.1796264	total: 3.35ms	remaining: 304us
# 11:	learn: 0.1789297	total: 3.65ms	remaining: 0us
# [CV 1/5; 34/360] END depth=1, learning_rate=1, num_trees=12;, score=0.178 total time=   0.0s
# [CV 2/5; 34/360] START depth=1, learning_rate=1, num_trees=12...................
# 0:	learn: 0.2340183	total: 340us	remaining: 3.74ms
# 1:	learn: 0.1901325	total: 597us	remaining: 2.99ms
# 2:	learn: 0.1816508	total: 962us	remaining: 2.89ms
# 3:	learn: 0.1798322	total: 1.28ms	remaining: 2.56ms
# 4:	learn: 0.1795369	total: 1.6ms	remaining: 2.25ms
# 5:	learn: 0.1768303	total: 1.86ms	remaining: 1.86ms
# 6:	learn: 0.1757796	total: 2.14ms	remaining: 1.53ms
# 7:	learn: 0.1738494	total: 2.41ms	remaining: 1.21ms
# 8:	learn: 0.1737469	total: 2.73ms	remaining: 911us
# 9:	learn: 0.1732352	total: 3.58ms	remaining: 716us
# 10:	learn: 0.1721129	total: 3.91ms	remaining: 355us
# 11:	learn: 0.1710337	total: 4.24ms	remaining: 0us
# [CV 2/5; 34/360] END depth=1, learning_rate=1, num_trees=12;, score=0.103 total time=   0.0s
# [CV 3/5; 34/360] START depth=1, learning_rate=1, num_trees=12...................
# 0:	learn: 0.2293695	total: 395us	remaining: 4.35ms
# 1:	learn: 0.1990807	total: 655us	remaining: 3.28ms
# 2:	learn: 0.1928661	total: 928us	remaining: 2.78ms
# 3:	learn: 0.1915662	total: 1.19ms	remaining: 2.38ms
# 4:	learn: 0.1896898	total: 1.46ms	remaining: 2.05ms
# 5:	learn: 0.1887310	total: 1.73ms	remaining: 1.73ms
# 6:	learn: 0.1882070	total: 2.06ms	remaining: 1.47ms
# 7:	learn: 0.1866561	total: 2.33ms	remaining: 1.16ms
# 8:	learn: 0.1855376	total: 2.61ms	remaining: 871us
# 9:	learn: 0.1836630	total: 2.94ms	remaining: 587us
# 10:	learn: 0.1824568	total: 3.25ms	remaining: 295us
# 11:	learn: 0.1814920	total: 3.54ms	remaining: 0us
# [CV 3/5; 34/360] END depth=1, learning_rate=1, num_trees=12;, score=0.100 total time=   0.1s
# [CV 1/5; 2/360] START depth=1, learning_rate=0.1, num_trees=4...................
# 0:	learn: 0.5751838	total: 63.1ms	remaining: 189ms
# 1:	learn: 0.4918819	total: 63.5ms	remaining: 63.5ms
# 2:	learn: 0.4260988	total: 63.9ms	remaining: 21.3ms
# 3:	learn: 0.3808943	total: 64.3ms	remaining: 0us
# [CV 1/5; 2/360] END depth=1, learning_rate=0.1, num_trees=4;, score=0.000 total time=   0.1s
# [CV 2/5; 4/360] START depth=1, learning_rate=0.1, num_trees=12..................
# 0:	learn: 0.5836744	total: 435us	remaining: 4.79ms
# 1:	learn: 0.4965348	total: 747us	remaining: 3.73ms
# 22:	learn: 0.1907523	total: 10.2ms	remaining: 884us
# 23:	learn: 0.1903153	total: 10.4ms	remaining: 435us
# 24:	learn: 0.1897757	total: 10.7ms	remaining: 0us
# [CV 5/5; 12/360] END depth=1, learning_rate=0.15, num_trees=25;, score=0.000 total time=   0.0s
# [CV 4/5; 16/360] START depth=1, learning_rate=0.25, num_trees=12................
# 0:	learn: 0.4434771	total: 375us	remaining: 4.13ms
# 1:	learn: 0.3293385	total: 657us	remaining: 3.29ms
# 2:	learn: 0.2715287	total: 937us	remaining: 2.81ms
# 3:	learn: 0.2274979	total: 1.22ms	remaining: 2.44ms
# 4:	learn: 0.2123453	total: 1.54ms	remaining: 2.16ms
# 5:	learn: 0.2063383	total: 1.95ms	remaining: 1.95ms
# 6:	learn: 0.2004211	total: 2.28ms	remaining: 1.63ms
# 7:	learn: 0.1926661	total: 2.56ms	remaining: 1.28ms
# 8:	learn: 0.1905329	total: 2.82ms	remaining: 939us
# 9:	learn: 0.1869215	total: 3.13ms	remaining: 625us
# 10:	learn: 0.1850298	total: 3.4ms	remaining: 309us
# 11:	learn: 0.1840008	total: 3.67ms	remaining: 0us
# [CV 4/5; 16/360] END depth=1, learning_rate=0.25, num_trees=12;, score=0.000 total time=   0.0s
# [CV 5/5; 16/360] START depth=1, learning_rate=0.25, num_trees=12................
# 0:	learn: 0.4535309	total: 50.3ms	remaining: 553ms
# 1:	learn: 0.3090112	total: 58.9ms	remaining: 295ms
# 2:	learn: 0.2645630	total: 59.9ms	remaining: 180ms
# 3:	learn: 0.2402645	total: 110ms	remaining: 220ms
# 4:	learn: 0.2190444	total: 117ms	remaining: 164ms
# 5:	learn: 0.2102840	total: 117ms	remaining: 117ms
# 6:	learn: 0.2033781	total: 117ms	remaining: 83.9ms
# 7:	learn: 0.2005570	total: 118ms	remaining: 58.9ms
# 8:	learn: 0.1989839	total: 118ms	remaining: 39.3ms
# 9:	learn: 0.1958742	total: 118ms	remaining: 23.7ms
# 10:	learn: 0.1937216	total: 119ms	remaining: 10.8ms
# 11:	learn: 0.1929164	total: 119ms	remaining: 0us
# [CV 5/5; 16/360] END depth=1, learning_rate=0.25, num_trees=12;, score=0.000 total time=   0.1s
# [CV 2/5; 20/360] START depth=1, learning_rate=0.5, num_trees=4..................
# 0:	learn: 0.3144284	total: 365us	remaining: 1.09ms
# 1:	learn: 0.2073251	total: 893us	remaining: 893us
# 2:	learn: 0.1991953	total: 1.21ms	remaining: 402us
# 3:	learn: 0.1946097	total: 1.5ms	remaining: 0us
# [CV 2/5; 20/360] END depth=1, learning_rate=0.5, num_trees=4;, score=0.000 total time=   0.0s
# [CV 3/5; 20/360] START depth=1, learning_rate=0.5, num_trees=4..................
# 0:	learn: 0.3063554	total: 414us	remaining: 1.24ms
# 1:	learn: 0.2161873	total: 716us	remaining: 716us
# 2:	learn: 0.2017604	total: 980us	remaining: 326us
# 3:	learn: 0.1951578	total: 1.29ms	remaining: 0us
# [CV 3/5; 20/360] END depth=1, learning_rate=0.5, num_trees=4;, score=0.000 total time=   0.0s
# [CV 3/5; 27/360] START depth=1, learning_rate=0.8, num_trees=6..................
# 0:	learn: 0.2389856	total: 359us	remaining: 1.8ms
# 1:	learn: 0.2000784	total: 631us	remaining: 1.26ms
# 2:	learn: 0.1918868	total: 906us	remaining: 906us
# 3:	learn: 0.1901780	total: 1.31ms	remaining: 654us
# 4:	learn: 0.1872241	total: 1.7ms	remaining: 339us
# 5:	learn: 0.1867859	total: 2.06ms	remaining: 0us
# [CV 3/5; 27/360] END depth=1, learning_rate=0.8, num_trees=6;, score=0.000 total time=   0.0s
# [CV 4/5; 27/360] START depth=1, learning_rate=0.8, num_trees=6..................
# 0:	learn: 0.2390519	total: 1.88ms	remaining: 9.39ms
# 1:	learn: 0.1980455	total: 2.17ms	remaining: 4.35ms
# 2:	learn: 0.1907033	total: 2.46ms	remaining: 2.46ms
# 3:	learn: 0.1850135	total: 2.73ms	remaining: 1.37ms
# 4:	learn: 0.1846431	total: 3.06ms	remaining: 611us
# 5:	learn: 0.1817673	total: 3.32ms	remaining: 0us
# [CV 4/5; 27/360] END depth=1, learning_rate=0.8, num_trees=6;, score=0.000 total time=   0.0s
# [CV 5/5; 27/360] START depth=1, learning_rate=0.8, num_trees=6..................
# 0:	learn: 0.2449614	total: 2.09ms	remaining: 10.4ms
# 1:	learn: 0.2014120	total: 3.58ms	remaining: 7.17ms
# 2:	learn: 0.1956087	total: 15.6ms	remaining: 15.6ms
# 3:	learn: 0.1921968	total: 15.9ms	remaining: 7.97ms
# 4:	learn: 0.1900784	total: 16.3ms	remaining: 3.25ms
# 5:	learn: 0.1878839	total: 18.3ms	remaining: 0us
# [CV 5/5; 27/360] END depth=1, learning_rate=0.8, num_trees=6;, score=0.054 total time=   0.1s
# [CV 1/5; 28/360] START depth=1, learning_rate=0.8, num_trees=12.................
# 0:	learn: 0.2388689	total: 397us	remaining: 4.37ms
# 1:	learn: 0.2012718	total: 665us	remaining: 3.33ms
# 2:	learn: 0.1934406	total: 1.08ms	remaining: 3.25ms
# 3:	learn: 0.1920922	total: 1.86ms	remaining: 3.72ms
# 4:	learn: 0.1911245	total: 2.49ms	remaining: 3.49ms
# 5:	learn: 0.1879560	total: 2.78ms	remaining: 2.78ms
# 6:	learn: 0.1854143	total: 3.07ms	remaining: 2.19ms
# 7:	learn: 0.1840787	total: 3.35ms	remaining: 1.67ms
# 8:	learn: 0.1817880	total: 3.63ms	remaining: 1.21ms
# 9:	learn: 0.1814018	total: 3.9ms	remaining: 780us
# 10:	learn: 0.1811713	total: 4.22ms	remaining: 383us
# 11:	learn: 0.1803142	total: 4.5ms	remaining: 0us
# [CV 1/5; 28/360] END depth=1, learning_rate=0.8, num_trees=12;, score=0.143 total time=   0.0s
# [CV 2/5; 36/360] START depth=1, learning_rate=1, num_trees=25...................
# 0:	learn: 0.2340183	total: 344us	remaining: 8.27ms
# 1:	learn: 0.1901325	total: 604us	remaining: 6.95ms
# 2:	learn: 0.1816508	total: 880us	remaining: 6.46ms
# 3:	learn: 0.1798322	total: 1.2ms	remaining: 6.29ms
# 12:	learn: 0.1725744	total: 5.73ms	remaining: 5.29ms
# 13:	learn: 0.1708609	total: 6.06ms	remaining: 4.76ms
# 14:	learn: 0.1698255	total: 6.36ms	remaining: 4.24ms
# 15:	learn: 0.1689342	total: 6.68ms	remaining: 3.76ms
# 16:	learn: 0.1684405	total: 6.99ms	remaining: 3.29ms
# 17:	learn: 0.1677237	total: 7.26ms	remaining: 2.82ms
# 18:	learn: 0.1671537	total: 7.53ms	remaining: 2.38ms
# 19:	learn: 0.1666379	total: 7.79ms	remaining: 1.95ms
# 20:	learn: 0.1657708	total: 8.17ms	remaining: 1.55ms
# 21:	learn: 0.1656562	total: 8.56ms	remaining: 1.17ms
# 22:	learn: 0.1654859	total: 8.82ms	remaining: 766us
# 23:	learn: 0.1652907	total: 9.13ms	remaining: 380us
# 24:	learn: 0.1649760	total: 9.39ms	remaining: 0us
# [CV 5/5; 36/360] END depth=1, learning_rate=1, num_trees=25;, score=0.204 total time=   0.0s
# [CV 3/5; 43/360] START depth=3, learning_rate=0.15, num_trees=2.................
# 0:	learn: 0.5008431	total: 610us	remaining: 610us
# 1:	learn: 0.4043248	total: 1.12ms	remaining: 0us
# [CV 4/5; 1/360] START depth=1, learning_rate=0.1, num_trees=2...................
# 0:	learn: 0.5775607	total: 63.2ms	remaining: 63.2ms
# 1:	learn: 0.4921497	total: 63.6ms	remaining: 0us
# [CV 4/5; 1/360] END depth=1, learning_rate=0.1, num_trees=2;, score=0.000 total time=   0.1s
# [CV 2/5; 3/360] START depth=1, learning_rate=0.1, num_trees=6...................
# 0:	learn: 0.5836744	total: 1.34ms	remaining: 6.7ms
# 1:	learn: 0.4965348	total: 1.78ms	remaining: 3.56ms
# 2:	learn: 0.4346303	total: 2.2ms	remaining: 2.2ms
# 3:	learn: 0.3641067	total: 2.65ms	remaining: 1.32ms
# 4:	learn: 0.3319986	total: 3.01ms	remaining: 601us
# 5:	learn: 0.3070840	total: 3.45ms	remaining: 0us
# [CV 2/5; 3/360] END depth=1, learning_rate=0.1, num_trees=6;, score=0.000 total time=   0.0s
# [CV 2/5; 5/360] START depth=1, learning_rate=0.1, num_trees=20..................
# 0:	learn: 0.5836744	total: 436us	remaining: 8.29ms
# 1:	learn: 0.4965348	total: 783us	remaining: 7.05ms
# 2:	learn: 0.4346303	total: 1.12ms	remaining: 6.36ms
# 3:	learn: 0.3641067	total: 1.57ms	remaining: 6.27ms
# 4:	learn: 0.3319986	total: 1.94ms	remaining: 5.81ms
# 5:	learn: 0.3070840	total: 2.31ms	remaining: 5.39ms
# 6:	learn: 0.2884061	total: 2.76ms	remaining: 5.13ms
# 7:	learn: 0.2611163	total: 3.16ms	remaining: 4.75ms
# 8:	learn: 0.2509372	total: 3.46ms	remaining: 4.24ms
# 9:	learn: 0.2397812	total: 3.91ms	remaining: 3.91ms
# 10:	learn: 0.2341873	total: 4.58ms	remaining: 3.75ms
# 11:	learn: 0.2222528	total: 5.05ms	remaining: 3.37ms
# 12:	learn: 0.2175800	total: 5.36ms	remaining: 2.89ms
# 13:	learn: 0.2098695	total: 5.69ms	remaining: 2.44ms
# 14:	learn: 0.2068956	total: 6ms	remaining: 2ms
# 15:	learn: 0.2017419	total: 6.37ms	remaining: 1.59ms
# 16:	learn: 0.1992232	total: 6.68ms	remaining: 1.18ms
# 17:	learn: 0.1975501	total: 7ms	remaining: 777us
# 18:	learn: 0.1959090	total: 7.29ms	remaining: 383us
# 19:	learn: 0.1946489	total: 7.59ms	remaining: 0us
# [CV 2/5; 5/360] END depth=1, learning_rate=0.1, num_trees=20;, score=0.000 total time=   0.0s
# [CV 1/5; 7/360] START depth=1, learning_rate=0.15, num_trees=2..................
# 0:	learn: 0.5249669	total: 417us	remaining: 417us
# 1:	learn: 0.4229554	total: 743us	remaining: 0us
# [CV 1/5; 7/360] END depth=1, learning_rate=0.15, num_trees=2;, score=0.000 total time=   0.0s
# [CV 1/5; 8/360] START depth=1, learning_rate=0.15, num_trees=4..................
# 0:	learn: 0.5249669	total: 399us	remaining: 1.2ms
# 1:	learn: 0.4229554	total: 1.77ms	remaining: 1.77ms
# 2:	learn: 0.3389639	total: 2.37ms	remaining: 791us
# 3:	learn: 0.3012999	total: 2.73ms	remaining: 0us
# [CV 1/5; 8/360] END depth=1, learning_rate=0.15, num_trees=4;, score=0.000 total time=   0.0s
# [CV 3/5; 10/360] START depth=1, learning_rate=0.15, num_trees=12................
# 0:	learn: 0.5277365	total: 413us	remaining: 4.54ms
# 1:	learn: 0.4242520	total: 693us	remaining: 3.47ms
# 2:	learn: 0.3539674	total: 992us	remaining: 2.98ms
# 3:	learn: 0.3129108	total: 1.27ms	remaining: 2.55ms
# 4:	learn: 0.2696913	total: 1.59ms	remaining: 2.23ms
# 5:	learn: 0.2434450	total: 1.89ms	remaining: 1.89ms
# 6:	learn: 0.2325022	total: 2.22ms	remaining: 1.58ms
# 7:	learn: 0.2251071	total: 2.6ms	remaining: 1.3ms
# 8:	learn: 0.2190338	total: 3.47ms	remaining: 1.16ms
# 9:	learn: 0.2109263	total: 3.78ms	remaining: 755us
# 10:	learn: 0.2065205	total: 4.07ms	remaining: 370us
# 11:	learn: 0.2042511	total: 4.38ms	remaining: 0us
# [CV 3/5; 10/360] END depth=1, learning_rate=0.15, num_trees=12;, score=0.000 total time=   0.0s
# [CV 2/5; 12/360] START depth=1, learning_rate=0.15, num_trees=25................
# 0:	learn: 0.5358013	total: 568us	remaining: 13.6ms
# 1:	learn: 0.4280854	total: 867us	remaining: 9.98ms
# 2:	learn: 0.3628230	total: 1.17ms	remaining: 8.54ms
# 3:	learn: 0.3001079	total: 1.47ms	remaining: 7.72ms
# 4:	learn: 0.2742548	total: 1.8ms	remaining: 7.21ms
# 5:	learn: 0.2413437	total: 2.16ms	remaining: 6.84ms
# 6:	learn: 0.2291491	total: 2.5ms	remaining: 6.42ms
# 7:	learn: 0.2136001	total: 2.81ms	remaining: 5.97ms
# 8:	learn: 0.2040071	total: 3.11ms	remaining: 5.53ms
# 9:	learn: 0.2000773	total: 3.41ms	remaining: 5.12ms
# 10:	learn: 0.1974968	total: 3.71ms	remaining: 4.72ms
# 11:	learn: 0.1950571	total: 4ms	remaining: 4.33ms
# 12:	learn: 0.1908784	total: 4.32ms	remaining: 3.99ms
# 13:	learn: 0.1881160	total: 4.63ms	remaining: 3.63ms
# 14:	learn: 0.1868273	total: 4.9ms	remaining: 3.27ms
# 15:	learn: 0.1859790	total: 5.19ms	remaining: 2.92ms
# 16:	learn: 0.1854345	total: 5.48ms	remaining: 2.58ms
# 17:	learn: 0.1845344	total: 5.76ms	remaining: 2.24ms
# 18:	learn: 0.1830678	total: 6.04ms	remaining: 1.91ms
# 19:	learn: 0.1820555	total: 6.32ms	remaining: 1.58ms
# 20:	learn: 0.1817099	total: 6.74ms	remaining: 1.28ms
# 21:	learn: 0.1809233	total: 7.05ms	remaining: 961us
# 22:	learn: 0.1802893	total: 8.01ms	remaining: 696us
# 23:	learn: 0.1802083	total: 8.38ms	remaining: 349us
# 24:	learn: 0.1800751	total: 8.72ms	remaining: 0us
# [CV 2/5; 12/360] END depth=1, learning_rate=0.15, num_trees=25;, score=0.000 total time=   0.0s
# [CV 1/5; 15/360] START depth=1, learning_rate=0.25, num_trees=6.................
# 0:	learn: 0.4405323	total: 384us	remaining: 1.92ms
# 1:	learn: 0.3300695	total: 743us	remaining: 1.49ms
# 2:	learn: 0.2743295	total: 1.03ms	remaining: 1.03ms
# 3:	learn: 0.2324890	total: 1.45ms	remaining: 727us
# 4:	learn: 0.2231467	total: 1.84ms	remaining: 367us
# 5:	learn: 0.2097002	total: 2.13ms	remaining: 0us
# [CV 1/5; 15/360] END depth=1, learning_rate=0.25, num_trees=6;, score=0.000 total time=   0.0s
# [CV 2/5; 15/360] START depth=1, learning_rate=0.25, num_trees=6.................
# 0:	learn: 0.4531621	total: 370us	remaining: 1.85ms
# 1:	learn: 0.2966815	total: 689us	remaining: 1.38ms
# 2:	learn: 0.2558422	total: 991us	remaining: 991us
# 3:	learn: 0.2231743	total: 1.28ms	remaining: 641us
# 4:	learn: 0.2093811	total: 1.62ms	remaining: 324us
# 5:	learn: 0.2026834	total: 1.93ms	remaining: 0us
# [CV 2/5; 15/360] END depth=1, learning_rate=0.25, num_trees=6;, score=0.000 total time=   0.1s
# [CV 3/5; 19/360] START depth=1, learning_rate=0.5, num_trees=2..................
# 0:	learn: 0.3063554	total: 483us	remaining: 483us
# 1:	learn: 0.2161873	total: 975us	remaining: 0us
# [CV 3/5; 19/360] END depth=1, learning_rate=0.5, num_trees=2;, score=0.000 total time=   0.0s
# [CV 4/5; 19/360] START depth=1, learning_rate=0.5, num_trees=2..................
# 0:	learn: 0.3064603	total: 380us	remaining: 380us
# 1:	learn: 0.2139249	total: 670us	remaining: 0us
# [CV 4/5; 19/360] END depth=1, learning_rate=0.5, num_trees=2;, score=0.000 total time=   0.0s
# [CV 5/5; 21/360] START depth=1, learning_rate=0.5, num_trees=6..................
# 0:	learn: 0.3151403	total: 414us	remaining: 2.07ms
# 1:	learn: 0.2181968	total: 689us	remaining: 1.38ms
# 2:	learn: 0.2103138	total: 1.01ms	remaining: 1.01ms
# 3:	learn: 0.2027651	total: 1.31ms	remaining: 655us
# 4:	learn: 0.1977873	total: 2.33ms	remaining: 466us
# 5:	learn: 0.1958027	total: 2.64ms	remaining: 0us
# [CV 5/5; 21/360] END depth=1, learning_rate=0.5, num_trees=6;, score=0.000 total time=   0.0s
# [CV 1/5; 22/360] START depth=1, learning_rate=0.5, num_trees=12.................
# 0:	learn: 0.3052658	total: 367us	remaining: 4.04ms
# 1:	learn: 0.2175546	total: 650us	remaining: 3.25ms
# 2:	learn: 0.2032558	total: 1.47ms	remaining: 4.41ms
# 3:	learn: 0.1966040	total: 2.39ms	remaining: 4.78ms
# 4:	learn: 0.1943601	total: 3.17ms	remaining: 4.44ms
# 5:	learn: 0.1926984	total: 3.46ms	remaining: 3.46ms
# 6:	learn: 0.1894980	total: 3.73ms	remaining: 2.66ms
# 7:	learn: 0.1883708	total: 4.02ms	remaining: 2.01ms
# 8:	learn: 0.1872047	total: 4.35ms	remaining: 1.45ms
# 9:	learn: 0.1844642	total: 4.67ms	remaining: 934us
# 10:	learn: 0.1839979	total: 4.93ms	remaining: 447us
# 11:	learn: 0.1833185	total: 5.27ms	remaining: 0us
# [CV 1/5; 22/360] END depth=1, learning_rate=0.5, num_trees=12;, score=0.054 total time=   0.0s
# [CV 2/5; 22/360] START depth=1, learning_rate=0.5, num_trees=12.................
# 0:	learn: 0.3144284	total: 1.07ms	remaining: 11.8ms
# 1:	learn: 0.2073251	total: 1.48ms	remaining: 7.4ms
# 2:	learn: 0.1991953	total: 1.84ms	remaining: 5.52ms
# 3:	learn: 0.1946097	total: 2.15ms	remaining: 4.31ms
# 4:	learn: 0.1880086	total: 2.49ms	remaining: 3.49ms
# 5:	learn: 0.1858322	total: 2.81ms	remaining: 2.81ms
# 6:	learn: 0.1811265	total: 3.09ms	remaining: 2.21ms
# 7:	learn: 0.1792910	total: 3.39ms	remaining: 1.69ms
# 8:	learn: 0.1782225	total: 3.79ms	remaining: 1.26ms
# 9:	learn: 0.1774696	total: 4.1ms	remaining: 819us
# 10:	learn: 0.1770622	total: 4.4ms	remaining: 400us
# 11:	learn: 0.1768264	total: 4.75ms	remaining: 0us
# [CV 2/5; 22/360] END depth=1, learning_rate=0.5, num_trees=12;, score=0.054 total time=   0.0s
# [CV 3/5; 22/360] START depth=1, learning_rate=0.5, num_trees=12.................
# 0:	learn: 0.3063554	total: 421us	remaining: 4.63ms
# 1:	learn: 0.2161873	total: 747us	remaining: 3.74ms
# 2:	learn: 0.2017604	total: 1.05ms	remaining: 3.16ms
# 3:	learn: 0.1951578	total: 1.38ms	remaining: 2.77ms
# 4:	learn: 0.1927275	total: 1.89ms	remaining: 2.64ms
# 5:	learn: 0.1924543	total: 2.39ms	remaining: 2.39ms
# 6:	learn: 0.1896641	total: 3.14ms	remaining: 2.24ms
# 7:	learn: 0.1884565	total: 3.83ms	remaining: 1.91ms
# 8:	learn: 0.1877999	total: 4.48ms	remaining: 1.49ms
# 9:	learn: 0.1867057	total: 5.17ms	remaining: 1.03ms
# 10:	learn: 0.1857376	total: 6.02ms	remaining: 547us
# 19:	learn: 0.1726016	total: 6.23ms	remaining: 1.56ms
# 20:	learn: 0.1702501	total: 6.57ms	remaining: 1.25ms
# 21:	learn: 0.1691860	total: 6.86ms	remaining: 935us
# 22:	learn: 0.1688180	total: 7.18ms	remaining: 624us
# 23:	learn: 0.1683358	total: 7.48ms	remaining: 311us
# 24:	learn: 0.1678697	total: 7.76ms	remaining: 0us
# [CV 1/5; 30/360] END depth=1, learning_rate=0.8, num_trees=25;, score=0.286 total time=   0.0s
# [CV 2/5; 30/360] START depth=1, learning_rate=0.8, num_trees=25.................
# 0:	learn: 0.2440930	total: 381us	remaining: 9.16ms
# 1:	learn: 0.1913893	total: 680us	remaining: 7.83ms
# 2:	learn: 0.1834256	total: 963us	remaining: 7.07ms
# 3:	learn: 0.1802852	total: 1.24ms	remaining: 6.52ms
# ...
# 20:	learn: 0.1244190	total: 1.11s	remaining: 212ms
# 21:	learn: 0.1209579	total: 1.17s	remaining: 159ms
# 22:	learn: 0.1177626	total: 1.21s	remaining: 105ms
# 23:	learn: 0.1164422	total: 1.28s	remaining: 53.5ms
# 24:	learn: 0.1144278	total: 1.32s	remaining: 0us
# [CV 1/5; 192/360] END depth=11, learning_rate=0.15, num_trees=25;, score=0.182 total time=   1.4s
# [CV 1/5; 205/360] START depth=11, learning_rate=0.8, num_trees=2................
# 0:	learn: 0.1987075	total: 48.4ms	remaining: 48.4ms
# 1:	learn: 0.1625992	total: 54ms	remaining: 0us
# [CV 1/5; 205/360] END depth=11, learning_rate=0.8, num_trees=2;, score=0.051 total time=   0.1s
# [CV 3/5; 205/360] START depth=11, learning_rate=0.8, num_trees=2................
# 0:	learn: 0.1979926	total: 99.4ms	remaining: 99.4ms
# 1:	learn: 0.1611810	total: 131ms	remaining: 0us
# [CV 3/5; 205/360] END depth=11, learning_rate=0.8, num_trees=2;, score=0.136 total time=   0.2s
# [CV 1/5; 206/360] START depth=11, learning_rate=0.8, num_trees=4................
# 0:	learn: 0.1987075	total: 51.1ms	remaining: 153ms
# 1:	learn: 0.1625992	total: 82.8ms	remaining: 82.8ms
# 2:	learn: 0.1337927	total: 165ms	remaining: 55.2ms
# 3:	learn: 0.1239793	total: 215ms	remaining: 0us
# [CV 1/5; 206/360] END depth=11, learning_rate=0.8, num_trees=4;, score=0.231 total time=   0.2s
# [CV 4/5; 206/360] START depth=11, learning_rate=0.8, num_trees=4................
# 0:	learn: 0.2174069	total: 35.2ms	remaining: 106ms
# 1:	learn: 0.1485312	total: 85ms	remaining: 85ms
# 2:	learn: 0.1304277	total: 125ms	remaining: 41.7ms
# 3:	learn: 0.1234248	total: 137ms	remaining: 0us
# [CV 4/5; 206/360] END depth=11, learning_rate=0.8, num_trees=4;, score=0.240 total time=   0.2s
# [CV 3/5; 207/360] START depth=11, learning_rate=0.8, num_trees=6................
# 0:	learn: 0.1979926	total: 103ms	remaining: 513ms
# 1:	learn: 0.1611810	total: 168ms	remaining: 336ms
# 2:	learn: 0.1262630	total: 193ms	remaining: 193ms
# 3:	learn: 0.1157191	total: 247ms	remaining: 124ms
# [CV 4/5; 211/360] END depth=11, learning_rate=1, num_trees=2;, score=0.133 total time=   0.1s
# [CV 4/5; 212/360] START depth=11, learning_rate=1, num_trees=4..................
# 0:	learn: 0.2065548	total: 74ms	remaining: 222ms
# 1:	learn: 0.1418823	total: 106ms	remaining: 106ms
# 2:	learn: 0.1270247	total: 137ms	remaining: 45.5ms
# 3:	learn: 0.1127833	total: 177ms	remaining: 0us
# [CV 4/5; 212/360] END depth=11, learning_rate=1, num_trees=4;, score=0.185 total time=   0.3s
# [CV 3/5; 213/360] START depth=11, learning_rate=1, num_trees=6..................
# 0:	learn: 0.1889051	total: 40.9ms	remaining: 204ms
# 1:	learn: 0.1481021	total: 73.8ms	remaining: 148ms
# 2:	learn: 0.1238766	total: 110ms	remaining: 110ms
# 3:	learn: 0.1157634	total: 274ms	remaining: 137ms
# 4:	learn: 0.1141740	total: 275ms	remaining: 55ms
# 5:	learn: 0.1037798	total: 304ms	remaining: 0us
# [CV 3/5; 213/360] END depth=11, learning_rate=1, num_trees=6;, score=0.250 total time=   0.3s
# [CV 3/5; 215/360] START depth=11, learning_rate=1, num_trees=20.................
# 0:	learn: 0.1889051	total: 60.6ms	remaining: 1.15s
# 1:	learn: 0.1481021	total: 89.4ms	remaining: 805ms
# 2:	learn: 0.1238766	total: 134ms	remaining: 761ms
# 3:	learn: 0.1157634	total: 177ms	remaining: 709ms
# 4:	learn: 0.1141740	total: 178ms	remaining: 533ms
# 5:	learn: 0.1037798	total: 211ms	remaining: 493ms
# 6:	learn: 0.0935979	total: 263ms	remaining: 489ms
# 7:	learn: 0.0827737	total: 304ms	remaining: 455ms
# 8:	learn: 0.0733358	total: 339ms	remaining: 414ms
# 9:	learn: 0.0615091	total: 386ms	remaining: 386ms
# 10:	learn: 0.0555838	total: 425ms	remaining: 348ms
# 11:	learn: 0.0468955	total: 456ms	remaining: 304ms
# 12:	learn: 0.0429263	total: 501ms	remaining: 270ms
# 13:	learn: 0.0362025	total: 562ms	remaining: 241ms
# 14:	learn: 0.0330024	total: 609ms	remaining: 203ms
# 15:	learn: 0.0290571	total: 662ms	remaining: 165ms
# 16:	learn: 0.0271269	total: 701ms	remaining: 124ms
# 17:	learn: 0.0261310	total: 752ms	remaining: 83.5ms
# 18:	learn: 0.0242360	total: 797ms	remaining: 42ms
# 19:	learn: 0.0224209	total: 837ms	remaining: 0us
# [CV 3/5; 215/360] END depth=11, learning_rate=1, num_trees=20;, score=0.259 total time=   0.9s
# [CV 1/5; 217/360] START depth=13, learning_rate=0.1, num_trees=2................
# 0:	learn: 0.5505035	total: 144ms	remaining: 144ms
# 1:	learn: 0.4538106	total: 251ms	remaining: 0us
# [CV 1/5; 217/360] END depth=13, learning_rate=0.1, num_trees=2;, score=0.000 total time=   0.3s
# [CV 1/5; 218/360] START depth=13, learning_rate=0.1, num_trees=4................
# 0:	learn: 0.5505035	total: 159ms	remaining: 478ms
# 1:	learn: 0.4538106	total: 260ms	remaining: 260ms
# 2:	learn: 0.3928782	total: 298ms	remaining: 99.3ms
# 3:	learn: 0.3345699	total: 470ms	remaining: 0us
# [CV 1/5; 218/360] END depth=13, learning_rate=0.1, num_trees=4;, score=0.000 total time=   0.5s
# [CV 4/5; 219/360] START depth=13, learning_rate=0.1, num_trees=6................
# 0:	learn: 0.5683259	total: 123ms	remaining: 615ms
# 1:	learn: 0.4581643	total: 294ms	remaining: 587ms
# 2:	learn: 0.3958375	total: 334ms	remaining: 334ms
# 3:	learn: 0.3354010	total: 511ms	remaining: 255ms
# 4:	learn: 0.2922594	total: 726ms	remaining: 145ms
# 5:	learn: 0.2551126	total: 945ms	remaining: 0us
# [CV 4/5; 219/360] END depth=13, learning_rate=0.1, num_trees=6;, score=0.000 total time=   1.0s
# [CV 3/5; 221/360] START depth=13, learning_rate=0.1, num_trees=20...............
# 0:	learn: 0.5508093	total: 277ms	remaining: 5.27s
# 1:	learn: 0.4516098	total: 377ms	remaining: 3.39s
# 2:	learn: 0.3787842	total: 428ms	remaining: 2.42s
# 3:	learn: 0.3243028	total: 877ms	remaining: 3.51s
# 4:	learn: 0.2870165	total: 1.22s	remaining: 3.66s
# 5:	learn: 0.2509532	total: 1.56s	remaining: 3.64s
# 6:	learn: 0.2339321	total: 1.56s	remaining: 2.9s
# 7:	learn: 0.2161616	total: 1.83s	remaining: 2.75s
# 8:	learn: 0.2084000	total: 1.86s	remaining: 2.27s
# 9:	learn: 0.1966519	total: 2.21s	remaining: 2.21s
# 10:	learn: 0.1856879	total: 2.44s	remaining: 2s
# 11:	learn: 0.1782748	total: 2.6s	remaining: 1.74s
# 12:	learn: 0.1733457	total: 2.62s	remaining: 1.41s
# 13:	learn: 0.1689488	total: 2.64s	remaining: 1.13s
# 14:	learn: 0.1612331	total: 2.77s	remaining: 922ms
# 15:	learn: 0.1552584	total: 3.05s	remaining: 762ms
# 16:	learn: 0.1502757	total: 3.3s	remaining: 582ms
# 17:	learn: 0.1452777	total: 3.61s	remaining: 402ms
# 18:	learn: 0.1416845	total: 3.84s	remaining: 202ms
# 19:	learn: 0.1375472	total: 4.08s	remaining: 0us
# [CV 3/5; 221/360] END depth=13, learning_rate=0.1, num_trees=20;, score=0.267 total time=   4.2s
# [CV 1/5; 223/360] START depth=13, learning_rate=0.15, num_trees=2...............
# 0:	learn: 0.4916490	total: 658ms	remaining: 658ms
# 1:	learn: 0.3777680	total: 892ms	remaining: 0us
# [CV 1/5; 223/360] END depth=13, learning_rate=0.15, num_trees=2;, score=0.000 total time=   1.0s
# [CV 2/5; 223/360] START depth=13, learning_rate=0.15, num_trees=2...............
# 0:	learn: 0.4870160	total: 413ms	remaining: 413ms
# 1:	learn: 0.3607826	total: 1.08s	remaining: 0us
# [CV 2/5; 223/360] END depth=13, learning_rate=0.15, num_trees=2;, score=0.000 total time=   1.4s
# [CV 4/5; 224/360] START depth=13, learning_rate=0.15, num_trees=4...............
# 0:	learn: 0.5152418	total: 485ms	remaining: 1.45s
# 1:	learn: 0.3815488	total: 545ms	remaining: 545ms
# 2:	learn: 0.3188133	total: 592ms	remaining: 197ms
# 3:	learn: 0.2627989	total: 845ms	remaining: 0us
# [CV 4/5; 224/360] END depth=13, learning_rate=0.15, num_trees=4;, score=0.000 total time=   0.9s
# [CV 2/5; 225/360] START depth=13, learning_rate=0.15, num_trees=6...............
# 0:	learn: 0.4870160	total: 126ms	remaining: 632ms
# 1:	learn: 0.3607826	total: 307ms	remaining: 613ms
# 2:	learn: 0.2934370	total: 552ms	remaining: 552ms
# 3:	learn: 0.2441906	total: 880ms	remaining: 440ms
# 4:	learn: 0.2094893	total: 1.16s	remaining: 232ms
# 5:	learn: 0.1871729	total: 1.56s	remaining: 0us
# [CV 2/5; 225/360] END depth=13, learning_rate=0.15, num_trees=6;, score=0.000 total time=   1.7s
# [CV 4/5; 227/360] START depth=13, learning_rate=0.15, num_trees=20..............
# 0:	learn: 0.5152418	total: 223ms	remaining: 4.24s
# 1:	learn: 0.3815488	total: 297ms	remaining: 2.67s
# 2:	learn: 0.3188133	total: 316ms	remaining: 1.79s
# 3:	learn: 0.2627989	total: 459ms	remaining: 1.84s
# 4:	learn: 0.2197303	total: 736ms	remaining: 2.21s
# 5:	learn: 0.1948579	total: 1.03s	remaining: 2.42s
# 6:	learn: 0.1790145	total: 1.19s	remaining: 2.21s
# 7:	learn: 0.1717924	total: 1.19s	remaining: 1.79s
# 8:	learn: 0.1648892	total: 1.2s	remaining: 1.47s
# 9:	learn: 0.1547861	total: 1.44s	remaining: 1.44s
# 10:	learn: 0.1450812	total: 1.66s	remaining: 1.36s
# 11:	learn: 0.1374537	total: 2.01s	remaining: 1.34s
# 12:	learn: 0.1298658	total: 2.13s	remaining: 1.15s
# 13:	learn: 0.1231792	total: 2.43s	remaining: 1.04s
# 14:	learn: 0.1182827	total: 2.69s	remaining: 896ms
# 15:	learn: 0.1143679	total: 3.01s	remaining: 753ms
# 16:	learn: 0.1114206	total: 3.25s	remaining: 574ms
# 17:	learn: 0.1087745	total: 3.4s	remaining: 378ms
# 18:	learn: 0.1061620	total: 3.56s	remaining: 187ms
# 19:	learn: 0.1027533	total: 3.99s	remaining: 0us
# [CV 4/5; 227/360] END depth=13, learning_rate=0.15, num_trees=20;, score=0.100 total time=   4.0s
# [CV 1/5; 229/360] START depth=13, learning_rate=0.25, num_trees=2...............
# 0:	learn: 0.3963249	total: 214ms	remaining: 214ms
# 1:	learn: 0.2786584	total: 588ms	remaining: 0us
# [CV 1/5; 229/360] END depth=13, learning_rate=0.25, num_trees=2;, score=0.000 total time=   0.6s
# [CV 4/5; 229/360] START depth=13, learning_rate=0.25, num_trees=2...............
# 0:	learn: 0.4262762	total: 307ms	remaining: 307ms
# 1:	learn: 0.2805845	total: 366ms	remaining: 0us
# [CV 4/5; 229/360] END depth=13, learning_rate=0.25, num_trees=2;, score=0.000 total time=   0.4s
# [CV 1/5; 230/360] START depth=13, learning_rate=0.25, num_trees=4...............
# 0:	learn: 0.3963249	total: 485ms	remaining: 1.46s
# 1:	learn: 0.2786584	total: 791ms	remaining: 791ms
# 2:	learn: 0.2207380	total: 809ms	remaining: 270ms
# 3:	learn: 0.1900470	total: 1.06s	remaining: 0us
# [CV 1/5; 230/360] END depth=13, learning_rate=0.25, num_trees=4;, score=0.054 total time=   1.2s
# [CV 5/5; 231/360] START depth=13, learning_rate=0.25, num_trees=6...............
# 0:	learn: 0.4522660	total: 11ms	remaining: 55.1ms
# 1:	learn: 0.2957175	total: 14.1ms	remaining: 28.2ms
# 2:	learn: 0.2554420	total: 14.6ms	remaining: 14.6ms
# 3:	learn: 0.2284025	total: 20.4ms	remaining: 10.2ms
# 4:	learn: 0.1913987	total: 382ms	remaining: 76.4ms
# 5:	learn: 0.1684719	total: 669ms	remaining: 0us
# [CV 5/5; 231/360] END depth=13, learning_rate=0.25, num_trees=6;, score=0.000 total time=   0.7s
# [CV 3/5; 232/360] START depth=13, learning_rate=0.25, num_trees=12..............
# 0:	learn: 0.3962584	total: 246ms	remaining: 2.71s
# 1:	learn: 0.2721925	total: 586ms	remaining: 2.93s
# 2:	learn: 0.2214687	total: 589ms	remaining: 1.77s
# 3:	learn: 0.1895655	total: 835ms	remaining: 1.67s
# 4:	learn: 0.1706587	total: 1.01s	remaining: 1.41s
# 5:	learn: 0.1577839	total: 1.28s	remaining: 1.28s
# 6:	learn: 0.1426212	total: 1.73s	remaining: 1.24s
# 7:	learn: 0.1340401	total: 1.9s	remaining: 952ms
# 8:	learn: 0.1256355	total: 2.32s	remaining: 773ms
# 9:	learn: 0.1189730	total: 2.64s	remaining: 529ms
# 10:	learn: 0.1134819	total: 2.77s	remaining: 252ms
# 11:	learn: 0.1076392	total: 3.12s	remaining: 0us
# [CV 3/5; 232/360] END depth=13, learning_rate=0.25, num_trees=12;, score=0.273 total time=   3.2s
# [CV 2/5; 234/360] START depth=13, learning_rate=0.25, num_trees=25..............
# 0:	learn: 0.3897468	total: 237ms	remaining: 5.7s
# 1:	learn: 0.2635290	total: 542ms	remaining: 6.23s
# 2:	learn: 0.2143529	total: 929ms	remaining: 6.81s
# 3:	learn: 0.1812297	total: 1.13s	remaining: 5.92s
# 4:	learn: 0.1577495	total: 1.83s	remaining: 7.3s
# 5:	learn: 0.1435456	total: 2.07s	remaining: 6.57s
# 6:	learn: 0.1345632	total: 2.34s	remaining: 6.02s
# 7:	learn: 0.1226269	total: 2.64s	remaining: 5.6s
# 8:	learn: 0.1166265	total: 2.95s	remaining: 5.25s
# 9:	learn: 0.1107537	total: 3.31s	remaining: 4.97s
# 10:	learn: 0.1099152	total: 3.32s	remaining: 4.23s
# 11:	learn: 0.1052000	total: 3.72s	remaining: 4.03s
# 12:	learn: 0.1015328	total: 3.97s	remaining: 3.67s
# 13:	learn: 0.0978187	total: 4.1s	remaining: 3.22s
# 14:	learn: 0.0972874	total: 4.1s	remaining: 2.73s
# 15:	learn: 0.0953081	total: 4.15s	remaining: 2.33s
# 16:	learn: 0.0913133	total: 4.59s	remaining: 2.16s
# 17:	learn: 0.0894747	total: 5.13s	remaining: 2s
# 18:	learn: 0.0866862	total: 5.49s	remaining: 1.73s
# 19:	learn: 0.0852212	total: 5.67s	remaining: 1.42s
# 20:	learn: 0.0828582	total: 5.97s	remaining: 1.14s
# 21:	learn: 0.0793871	total: 6.2s	remaining: 845ms
# 22:	learn: 0.0777155	total: 6.57s	remaining: 571ms
# 23:	learn: 0.0751270	total: 6.88s	remaining: 287ms
# 24:	learn: 0.0728156	total: 7.17s	remaining: 0us
# [CV 2/5; 234/360] END depth=13, learning_rate=0.25, num_trees=25;, score=0.222 total time=   7.3s
# [CV 4/5; 239/360] START depth=13, learning_rate=0.5, num_trees=20...............
# 0:	learn: 0.2861402	total: 237ms	remaining: 4.51s
# 1:	learn: 0.1782690	total: 419ms	remaining: 3.77s
# 2:	learn: 0.1428143	total: 625ms	remaining: 3.54s
# 3:	learn: 0.1258734	total: 846ms	remaining: 3.38s
# 4:	learn: 0.1168805	total: 1.1s	remaining: 3.31s
# 5:	learn: 0.1036032	total: 1.24s	remaining: 2.89s
# 6:	learn: 0.0953765	total: 1.45s	remaining: 2.69s
# 7:	learn: 0.0914476	total: 1.7s	remaining: 2.54s
# 8:	learn: 0.0854046	total: 1.83s	remaining: 2.24s
# 9:	learn: 0.0808882	total: 2.09s	remaining: 2.09s
# 10:	learn: 0.0776778	total: 2.21s	remaining: 1.81s
# 11:	learn: 0.0745510	total: 2.37s	remaining: 1.58s
# 12:	learn: 0.0721400	total: 2.55s	remaining: 1.38s
# 13:	learn: 0.0695125	total: 2.7s	remaining: 1.16s

# %%
print('Лучшая глубина, learning_rate и кол-во деревьев :', cross_vall.best_params_)
print()
print('Лучший F1 score:', cross_vall.best_score_)

# %% [markdown]
# ```your comments here```

# %% [markdown]
# ### Task 4 <a id="task2_4"></a> (0.7 points)
#
# Now let's train more fancy ensembles:
#
# * Bagging with decision trees as base estimators
# * Bagging with gradient boosting (with large amount of trees, >100) as base estimators
# * [Voting classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.VotingClassifier.html#sklearn.ensemble.VotingClassifier)
# * [Stacking Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingClassifier.html#sklearn.ensemble.StackingClassifier) with Logistic Regression as a final model
# * [Stacking Classifier](https://scikit-learn.org/stable/modules/generated/sklearn.ensemble.StackingClassifier.html#sklearn.ensemble.StackingClassifier) with Gradeint Boosting as a final model
#
#
# If not stated in the task, feel free to tune / choose hyperparameters and base models.
#
# Answer the questions:
# * Which model has the best performance?
# * Does bagging reduce overfiting of the gradient boosting with large amount of trees?
# * What is the difference between voting and staking?

# %%
from sklearn.ensemble import BaggingClassifier

model = BaggingClassifier(base_estimator=DecisionTreeClassifier(random_state=987), random_state=987)
scores = cross_val_score(model, X_train, y_train, cv=folds, scoring='f1',n_jobs=-1)
final_score = sum(scores) / len(scores)

# %%
print(f'Средняя оценка качества модели {model}:', final_score)
model.fit(X_train, y_train)
print('Метрика на тестовой выборке:', f1_score(y_true=y_test, y_pred=model.predict(X_test)))

# %%
model = BaggingClassifier(base_estimator=GradientBoostingClassifier(n_estimators=1000, random_state=987), random_state=987)
scores = cross_val_score(model, X_train, y_train, cv=folds, scoring='f1',n_jobs=-1)
final_score = sum(scores) / len(scores)

# %%
print(f'Средняя оценка качества модели {model}:', final_score)
model.fit(X_train, y_train)
print('Метрика на тестовой выборке:', f1_score(y_true=y_test, y_pred=model.predict(X_test)))

# %%
from sklearn.ensemble import VotingClassifier

model = VotingClassifier(estimators=[('logistic', LogisticRegression()), ('forest', RandomForestClassifier()), ('svm', SVC()), ('tree', DecisionTreeClassifier()), ('gradient', GradientBoostingClassifier())])
scores = cross_val_score(model, X_train, y_train, cv=folds, scoring='f1', n_jobs=-1)
final_score = sum(scores) / len(scores)

# %%
print(f'Средняя оценка качества модели {model}:', final_score)
model.fit(X_train, y_train)
print('Метрика на тестовой выборке:', f1_score(y_true=y_test, y_pred=model.predict(X_test)))

# %%
from sklearn.ensemble import StackingClassifier


model = StackingClassifier(estimators=[('forest', RandomForestClassifier()), ('svm', SVC()), ('tree', DecisionTreeClassifier()), ('gradient', GradientBoostingClassifier())], final_estimator=LogisticRegression())

scores = cross_val_score(model, X_train, y_train, cv=folds, scoring='f1', n_jobs=-1)
final_score = sum(scores) / len(scores)

# %%
print(f'Средняя оценка качества модели {model}:', final_score)
model.fit(X_train, y_train)
print('Метрика на тестовой выборке:', f1_score(y_true=y_test, y_pred=model.predict(X_test)))

# %%
from sklearn.ensemble import StackingClassifier


model = StackingClassifier(estimators=[('logistic', LogisticRegression()),('forest', RandomForestClassifier()), ('svm', SVC()), ('tree', DecisionTreeClassifier())], final_estimator=GradientBoostingClassifier())

scores = cross_val_score(model, X_train, y_train, cv=folds, scoring='f1',n_jobs=-1)
final_score = sum(scores) / len(scores)

# %%
print(f'Средняя оценка качества модели {model}:', final_score)
model.fit(X_train, y_train)
print('Метрика на тестовой выборке:', f1_score(y_true=y_test, y_pred=model.predict(X_test)))

# %%
# %%time
import numpy as np

tmp = list()
for i in range(1000000000):
    tmp.append(10000000000000)

arr = np.array((tmp))

# arr = np.array([53425432,53245,235123,1243,1234,1234,1234,21543,123542,15152345,1435,135,54325342543254325,13211235,3754988888888888888880, 10924801732498710324, 91204983938034832481092480923,9876543567898765434567898765434567, 948000000000000000000003450982354980924802, 54325346453214321432452435,132451435435351343214124,1454325324535664235534276235,43253245243524354326251324,6543632453245132454325432654,13254354326523461454326263])
print(arr.sum())

# %%
# %%time
import numpy as np

tmp = list()
for i in range(1000000000):
    tmp.append(10000000000000)

arr = np.array((tmp))

# arr = np.array([53425432,53245,235123,1243,1234,1234,1234,21543,123542,15152345,1435,135,54325342543254325,13211235,3754988888888888888880, 10924801732498710324, 91204983938034832481092480923,9876543567898765434567898765434567, 948000000000000000000003450982354980924802, 54325346453214321432452435,132451435435351343214124,1454325324535664235534276235,43253245243524354326251324,6543632453245132454325432654,13254354326523461454326263])
print(np.sum(arr))

# %%
import numpy as np

# %%
# %%time

a = np.ones(int(1e9))

# %%
# %%time

a.sum()

# %%
# %%time
np.sum(a)

# %% [markdown]
# ```Учитывая тот факт, что гипперпараметры не подбирались, с лучшей стороны себя показала модель Bagging с base_estimator Gradient - 0.3 на тестовой выборке. Переобучения в этой модели не обнаружено. Возможно это связано опять же с тем, что не подбирались гипперпараметры. Voting показала себя намного лучше, чем Staking, опять же в рамках отсуствие подбора гипперпараметров.```

# %% [markdown]
# ### Task 5 <a id="task2_5"></a> (0.1 points)
#
# Report the test score for the best model, that you were able to train.

# %% [markdown]
# 0.3287671232876712
